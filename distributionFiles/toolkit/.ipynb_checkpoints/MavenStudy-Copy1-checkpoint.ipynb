# %%
import toolkit

# %% [markdown]
# ### First, we gather the dataset. This is a history of Java static code metrics and change metrics for our project.

# %%
# Used to indicate where the data should be gathered and stored
rootDirectory = '../dataSets/mavenStudy/'

# Call gatherTimeMetrics and measure Java and change metrics 
# on .java files from the git project's repository
metricsDataMaven = toolkit.data.gatherTimeMetrics(rootDirectory, 'https://github.com/apache/maven.git', rootDirectory+'maven/', '*/*.java *.java', ['java'], skipEvery=100)
metricsDataMaven['data'].to_csv(rootDirectory+"/my.csv")

# %%
metricsDataMaven['data']
# Out:
#                                                entity  age-months  n-authors  \
# 0   maven-artifact/src/main/java/org/apache/maven/...           0          1
# 1   maven-core/src/test/java/org/apache/maven/tool...           0          1
# 2   maven-embedder/src/test/error-reporting-projec...           0          1
# 3   maven-embedder/src/test/error-reporting-projec...           0          1
# 4   maven-embedder/src/test/error-reporting-projec...           0          1
# 5   maven-embedder/src/test/error-reporting-projec...           0          1
# 6   maven-embedder/src/test/error-reporting-projec...           0          1
# 7   maven-embedder/src/test/embedder-test-project/...           0          1
# 8   maven-embedder/src/test/error-reporting-projec...           0          1
# 9   maven-embedder/src/test/error-reporting-projec...           0          1
# 10  maven-embedder/src/main/java/org/apache/maven/...           0          2
# 11  maven-core/src/test/java/org/apache/maven/plug...           0          1
# 12  maven-embedder/src/test/error-reporting-projec...           0          1
# 13  maven-embedder/src/test/error-reporting-projec...           0          1
# 14  maven-embedder/src/test/error-reporting-projec...           0          1
# 15  maven-embedder/src/test/error-reporting-projec...           0          1
# 16  maven-embedder/src/test/java/org/apache/maven/...           0          2
# 17  maven-embedder/src/test/error-reporting-projec...           0          1
# 18  maven-embedder/src/main/java/org/apache/maven/...           0          2
# 19  maven-compat/src/main/java/org/apache/maven/pr...           0          1
# 20  maven-embedder/src/test/error-reporting-projec...           0          1
# 21  maven-embedder/src/test/error-reporting-projec...           0          1
# 22  maven-embedder/src/test/error-reporting-projec...           0          1
# 23  maven-embedder/src/test/error-reporting-projec...           0          1
# 24  maven-embedder/src/test/error-reporting-projec...           0          1
# 25  maven-embedder/src/test/error-reporting-projec...           0          1
# 26  maven-embedder/src/test/projects/isolated-proj...           0          1
# 27  maven-embedder/src/test/error-reporting-projec...           0          1
# 28  maven-embedder/src/test/error-reporting-projec...           0          1
# 29  maven-embedder/src/test/error-reporting-projec...           0          1
# ..                                                ...         ...        ...
# 30  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 31  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 32  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 33  maven-core/src/main/java/org/apache/maven/life...         183          2
# 34  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 35  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 36  maven-repository-tools/src/main/java/org/apach...         183          1
# 37  maven-repository-tools/src/main/java/org/apach...         183          1
# 38  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 39  maven-core/src/main/java/org/apache/maven/repo...         183          1
# 40  maven-artifact/src/test/java/org/apache/maven/...         183          1
# 41  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 42  maven-repository-tools/src/main/java/org/apach...         183          1
# 43  maven-repository-tools/src/main/java/org/apach...         183          1
# 44  maven-core/src/test/java/org/apache/maven/plug...         183          2
# 45  maven-core/src/main/java/org/apache/maven/JarO...         183          1
# 46  maven-core/src/main/java/org/apache/maven/proj...         183          1
# 47  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 48  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 49  maven-repository-tools/src/main/java/org/apach...         183          1
# 50  maven-repository-tools/src/main/java/org/apach...         183          1
# 51  maven-core/src/main/java/org/apache/maven/Mave...         183          2
# 52  maven-repository-tools/src/main/java/org/apach...         183          1
# 53  maven-repository-tools/src/main/java/org/apach...         183          1
# 54  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 55  maven-core/src/main/java/org/apache/maven/life...         183          3
# 56  maven-core/src/test/java/org/apache/maven/life...         184          1
# 0   maven-plugins/maven-surefire-plugin/src/main/j...         185          2
# 1   maven-plugins/maven-clean-plugin/src/main/java...         186          1
# 2   maven-plugins/maven-compiler-plugin/src/main/j...         186          1
#
#     n-revs  added  deleted  fractal-value  soc  netchurn cbo  ...  \
# 0        1      1        1           0.00    8         0   4  ...
# 1        1      1        1           0.00    8         0   4  ...
# 2        1      0       33           0.00   28       -33   3  ...
# 3        1      0       35           0.00   28       -35   2  ...
# 4        1      0       33           0.00   28       -33   3  ...
# 5        1      0       42           0.00   28       -42   4  ...
# 6        1      0       36           0.00   28       -36   3  ...
# 7        1      0       38           0.00   28       -38   4  ...
# 8        1      0        8           0.00   28        -8   1  ...
# 9        1      0       38           0.00   28       -38   4  ...
# 10       2      2        2           0.50   13         0   3  ...
# 11       1      1        1           0.00    8         0  21  ...
# 12       1      0       33           0.00   28       -33   3  ...
# 13       1      0       13           0.00   28       -13   0  ...
# 14       1      0       39           0.00   28       -39   3  ...
# 15       1      0       14           0.00   28       -14   1  ...
# 16       2      5        4           0.50   43         1   8  ...
# 17       1      0        8           0.00   28        -8   1  ...
# 18       2      2        2           0.50   13         0   3  ...
# 19       1      3        3           0.00    8         0   1  ...
# 20       1      0       38           0.00   28       -38   4  ...
# 21       1      0       38           0.00   28       -38   4  ...
# 22       1      0       50           0.00   28       -50   4  ...
# 23       1      0       36           0.00   28       -36   3  ...
# 24       1      0       38           0.00   28       -38   4  ...
# 25       1      0       38           0.00   28       -38   3  ...
# 26       1      0       38           0.00   28       -38   4  ...
# 27       1      0       33           0.00   28       -33   3  ...
# 28       1      0       13           0.00   28       -13   0  ...
# 29       1      0       13           0.00   28       -13   0  ...
# ..     ...    ...      ...            ...  ...       ...  ..  ...
# 30       1      0       74           0.00   17       -74   4  ...
# 31       2      4        9           0.00   49        -5   4  ...
# 32       1      0       92           0.00   17       -92   3  ...
# 33       2      3        2           0.50   29         1   3  ...
# 34       1      0       23           0.00   17       -23   0  ...
# 35       1      0       83           0.00   17       -83   2  ...
# 36       1      2        0           0.00   15         2   1  ...
# 37       1      0       39           0.00   15       -39   0  ...
# 38       2      5        6           0.00   49        -1   3  ...
# 39       1      6        1           0.00   25         5   3  ...
# 40       2     51        2           0.00   27        49  11  ...
# 41       1      3        3           0.00   24         0   6  ...
# 42       2      2        2           0.00   17         0   2  ...
# 43       1      0       86           0.00   15       -86   0  ...
# 44       2      2       18           0.50   50       -16   6  ...
# 45       2      2        4           0.00   49        -2   5  ...
# 46       1      0       32           0.00   25       -32   0  ...
# 47       2      4       27           0.00   49       -23   5  ...
# 48       1      0       43           0.00   17       -43   2  ...
# 49       2     41       12           0.00   17        29  23  ...
# 50       1      0       40           0.00   15       -40   0  ...
# 51       4     23       58           0.38   32       -35  13  ...
# 52       2     28        8           0.00   17        20   6  ...
# 53       1      0       85           0.00   15       -85   0  ...
# 54       1      0       88           0.00   17       -88   4  ...
# 55       3     14       14           0.67   54         0   4  ...
# 56       1      0       81           0.00   25       -81   4  ...
# 0        8     82       36           0.38   23        46   4  ...
# 1        2     35       36           0.00    8        -1   4  ...
# 2        1      0      117           0.00    7      -117   5  ...
#
#    assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# 0              19                 0           19               4
# 1               8                 4            8               0
# 2               1                 0            1               0
# 3               1                 0            1               0
# 4               1                 0            1               0
# 5               1                 0            2               0
# 6               1                 0            1               0
# 7               0                 0            0               0
# 8               0                 0            1              -1
# 9               0                 0            0               0
# 10              5                 1            5               2
# 11             84                13           83               1
# 12              1                 0            1               0
# 13              0                 0            0               0
# 14              1                 0            2               0
# 15              0                 0            1               0
# 16              6                 0            5               3
# 17              0                 0            1              -1
# 18             34                18           25               3
# 19              4                 1            4               1
# 20              0                 0            0               0
# 21              0                 0            0               0
# 22              1                 0            3               0
# 23              1                 0            1               0
# 24              0                 0            0               0
# 25              1                 0            2               0
# 26              0                 0            0               0
# 27              1                 0            1               0
# 28              0                 0            0               0
# 29              0                 0            0               0
# ..            ...               ...          ...             ...
# 30             20                 1           18               4
# 31              5                 5            5               0
# 32             16                 0           16               0
# 33              1                 0            1              -1
# 34              0                 0            0              -1
# 35             11                 0            7               1
# 36              0                 0            0              -1
# 37              0                 0            0              -1
# 38              5                 0            5               0
# 39              3                 0            3               1
# 40             21                 0           21               4
# 41             10                 1           10               0
# 42              8                 7            6               1
# 43              4                 0            4               0
# 44             12                 0           12               0
# 45              4                 1            4               1
# 46              4                 0            4              -1
# 47              4                 2            4               1
# 48              2                 0            2               0
# 49             95                16           86               3
# 50              0                 0            0               0
# 51             45                 3           35               3
# 52             12                 8           11               3
# 53              4                 0            4               0
# 54             10                 3           10               0
# 55              2                 0            3               2
# 56              6                 2            6               0
# 0               7                 0            7               1
# 1              11                 3           10               4
# 2              14                 1           12               3
#
#    anonymousClassesQty subClassesQty lambdasQty uniqueWordsQty modifiers  \
# 0                    0             0          0             76         1
# 1                    0             0          0             36         1
# 2                    0             0          0             15         1
# 3                    0             0          0             13         1
# 4                    0             0          0             15         1
# 5                    0             0          0             30         1
# 6                    0             0          0             26         1
# 7                    0             0          0             20         1
# 8                    0             0          0              4         1
# 9                    0             0          0             20         1
# 10                   0             0          0             32         1
# 11                   0             0          0            138         1
# 12                   0             0          0             15         1
# 13                   0             0          0              6         1
# 14                   0             0          0             13         1
# 15                   0             0          0              9         1
# 16                   0             2          0             79        21
# 17                   0             0          0              4         1
# 18                   0             0          0            102        17
# 19                   0             0          0             29         1
# 20                   0             0          0             20         1
# 21                   0             0          0             20         1
# 22                   0             0          0             18         1
# 23                   0             0          0             25         1
# 24                   0             0          0             20         1
# 25                   0             0          0             13         1
# 26                   0             0          0             20         1
# 27                   0             0          0             15         1
# 28                   0             0          0              6         1
# 29                   0             0          0              6         1
# ..                 ...           ...        ...            ...       ...
# 30                   0             0          0             47         1
# 31                   0             0          0             33      1025
# 32                   0             0          0             38         1
# 33                   0             0          0             18         1
# 34                   0             0          0             41         1
# 35                   0             0          0             24         1
# 36                   0             0          0             25         1
# 37                   0             0          0             16         1
# 38                   0             0          0             43         1
# 39                   0             0          0             18         1
# 40                   4            -2          0             65        -1
# 41                   0             0          0             45         1
# 42                   0             0          0             33         1
# 43                   0             0          0             21         1
# 44                   0             0          0             58         1
# 45                   0             0          0             19         1
# 46                   0             0          0             21         1
# 47                   0             0          0             44         1
# 48                   0             0          0             16         1
# 49                   0             0          0            146         1
# 50                   0             0          0             11         1
# 51                   0             1          0            159         9
# 52                   0             0          0             43         1
# 53                   0             0          0             21         1
# 54                   0             0          0             52         1
# 55                   0             0          0             27         1
# 56                   0             0          0             53         1
# 0                    0             0          0             51         1
# 1                    0             0          0             76         1
# 2                    0             0          0            100         1
#
#           time
# 0   2018-09-16
# 1   2018-09-16
# 2   2018-09-16
# 3   2018-09-16
# 4   2018-09-16
# 5   2018-09-16
# 6   2018-09-16
# 7   2018-09-16
# 8   2018-09-16
# 9   2018-09-16
# 10  2018-09-16
# 11  2018-09-16
# 12  2018-09-16
# 13  2018-09-16
# 14  2018-09-16
# 15  2018-09-16
# 16  2018-09-16
# 17  2018-09-16
# 18  2018-09-16
# 19  2018-09-16
# 20  2018-09-16
# 21  2018-09-16
# 22  2018-09-16
# 23  2018-09-16
# 24  2018-09-16
# 25  2018-09-16
# 26  2018-09-16
# 27  2018-09-16
# 28  2018-09-16
# 29  2018-09-16
# ..         ...
# 30  2004-08-14
# 31  2004-08-14
# 32  2004-08-14
# 33  2004-08-14
# 34  2004-08-14
# 35  2004-08-14
# 36  2004-08-14
# 37  2004-08-14
# 38  2004-08-14
# 39  2004-08-14
# 40  2004-08-14
# 41  2004-08-14
# 42  2004-08-14
# 43  2004-08-14
# 44  2004-08-14
# 45  2004-08-14
# 46  2004-08-14
# 47  2004-08-14
# 48  2004-08-14
# 49  2004-08-14
# 50  2004-08-14
# 51  2004-08-14
# 52  2004-08-14
# 53  2004-08-14
# 54  2004-08-14
# 55  2004-08-14
# 56  2004-08-14
# 0   2004-05-28
# 1   2004-05-28
# 2   2004-05-28
#
# [7689 rows x 50 columns]

# %% [markdown]
# ### How many times did we sample from?

# %%
print metricsDataMaven['times']
# Out:
# 61

# %% [markdown]
# ### How many features and samples are in our dataset?

# %%
print metricsDataMaven['data'].shape
# Out:
# (7689, 50)

# %% [markdown]
# ### How many unique source files were measured?

# %%
print metricsDataMaven['data']['entity'].nunique()
# Out:
# 2909

# %%
print metricsDataMaven['data'].head
# Out:
# <bound method DataFrame.head of                                                entity  age-months  n-authors  \
# 0   maven-artifact/src/main/java/org/apache/maven/...           0          1
# 1   maven-core/src/test/java/org/apache/maven/tool...           0          1
# 2   maven-embedder/src/test/error-reporting-projec...           0          1
# 3   maven-embedder/src/test/error-reporting-projec...           0          1
# 4   maven-embedder/src/test/error-reporting-projec...           0          1
# 5   maven-embedder/src/test/error-reporting-projec...           0          1
# 6   maven-embedder/src/test/error-reporting-projec...           0          1
# 7   maven-embedder/src/test/embedder-test-project/...           0          1
# 8   maven-embedder/src/test/error-reporting-projec...           0          1
# 9   maven-embedder/src/test/error-reporting-projec...           0          1
# 10  maven-embedder/src/main/java/org/apache/maven/...           0          2
# 11  maven-core/src/test/java/org/apache/maven/plug...           0          1
# 12  maven-embedder/src/test/error-reporting-projec...           0          1
# 13  maven-embedder/src/test/error-reporting-projec...           0          1
# 14  maven-embedder/src/test/error-reporting-projec...           0          1
# 15  maven-embedder/src/test/error-reporting-projec...           0          1
# 16  maven-embedder/src/test/java/org/apache/maven/...           0          2
# 17  maven-embedder/src/test/error-reporting-projec...           0          1
# 18  maven-embedder/src/main/java/org/apache/maven/...           0          2
# 19  maven-compat/src/main/java/org/apache/maven/pr...           0          1
# 20  maven-embedder/src/test/error-reporting-projec...           0          1
# 21  maven-embedder/src/test/error-reporting-projec...           0          1
# 22  maven-embedder/src/test/error-reporting-projec...           0          1
# 23  maven-embedder/src/test/error-reporting-projec...           0          1
# 24  maven-embedder/src/test/error-reporting-projec...           0          1
# 25  maven-embedder/src/test/error-reporting-projec...           0          1
# 26  maven-embedder/src/test/projects/isolated-proj...           0          1
# 27  maven-embedder/src/test/error-reporting-projec...           0          1
# 28  maven-embedder/src/test/error-reporting-projec...           0          1
# 29  maven-embedder/src/test/error-reporting-projec...           0          1
# ..                                                ...         ...        ...
# 30  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 31  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 32  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 33  maven-core/src/main/java/org/apache/maven/life...         183          2
# 34  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 35  maven-core/src/main/java/org/apache/maven/deco...         183          1
# 36  maven-repository-tools/src/main/java/org/apach...         183          1
# 37  maven-repository-tools/src/main/java/org/apach...         183          1
# 38  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 39  maven-core/src/main/java/org/apache/maven/repo...         183          1
# 40  maven-artifact/src/test/java/org/apache/maven/...         183          1
# 41  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 42  maven-repository-tools/src/main/java/org/apach...         183          1
# 43  maven-repository-tools/src/main/java/org/apach...         183          1
# 44  maven-core/src/test/java/org/apache/maven/plug...         183          2
# 45  maven-core/src/main/java/org/apache/maven/JarO...         183          1
# 46  maven-core/src/main/java/org/apache/maven/proj...         183          1
# 47  maven-core/src/test/java/org/apache/maven/proj...         183          1
# 48  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 49  maven-repository-tools/src/main/java/org/apach...         183          1
# 50  maven-repository-tools/src/main/java/org/apach...         183          1
# 51  maven-core/src/main/java/org/apache/maven/Mave...         183          2
# 52  maven-repository-tools/src/main/java/org/apach...         183          1
# 53  maven-repository-tools/src/main/java/org/apach...         183          1
# 54  maven-core/src/test/java/org/apache/maven/deco...         183          1
# 55  maven-core/src/main/java/org/apache/maven/life...         183          3
# 56  maven-core/src/test/java/org/apache/maven/life...         184          1
# 0   maven-plugins/maven-surefire-plugin/src/main/j...         185          2
# 1   maven-plugins/maven-clean-plugin/src/main/java...         186          1
# 2   maven-plugins/maven-compiler-plugin/src/main/j...         186          1
#
#     n-revs  added  deleted  fractal-value  soc  netchurn cbo  ...  \
# 0        1      1        1           0.00    8         0   4  ...
# 1        1      1        1           0.00    8         0   4  ...
# 2        1      0       33           0.00   28       -33   3  ...
# 3        1      0       35           0.00   28       -35   2  ...
# 4        1      0       33           0.00   28       -33   3  ...
# 5        1      0       42           0.00   28       -42   4  ...
# 6        1      0       36           0.00   28       -36   3  ...
# 7        1      0       38           0.00   28       -38   4  ...
# 8        1      0        8           0.00   28        -8   1  ...
# 9        1      0       38           0.00   28       -38   4  ...
# 10       2      2        2           0.50   13         0   3  ...
# 11       1      1        1           0.00    8         0  21  ...
# 12       1      0       33           0.00   28       -33   3  ...
# 13       1      0       13           0.00   28       -13   0  ...
# 14       1      0       39           0.00   28       -39   3  ...
# 15       1      0       14           0.00   28       -14   1  ...
# 16       2      5        4           0.50   43         1   8  ...
# 17       1      0        8           0.00   28        -8   1  ...
# 18       2      2        2           0.50   13         0   3  ...
# 19       1      3        3           0.00    8         0   1  ...
# 20       1      0       38           0.00   28       -38   4  ...
# 21       1      0       38           0.00   28       -38   4  ...
# 22       1      0       50           0.00   28       -50   4  ...
# 23       1      0       36           0.00   28       -36   3  ...
# 24       1      0       38           0.00   28       -38   4  ...
# 25       1      0       38           0.00   28       -38   3  ...
# 26       1      0       38           0.00   28       -38   4  ...
# 27       1      0       33           0.00   28       -33   3  ...
# 28       1      0       13           0.00   28       -13   0  ...
# 29       1      0       13           0.00   28       -13   0  ...
# ..     ...    ...      ...            ...  ...       ...  ..  ...
# 30       1      0       74           0.00   17       -74   4  ...
# 31       2      4        9           0.00   49        -5   4  ...
# 32       1      0       92           0.00   17       -92   3  ...
# 33       2      3        2           0.50   29         1   3  ...
# 34       1      0       23           0.00   17       -23   0  ...
# 35       1      0       83           0.00   17       -83   2  ...
# 36       1      2        0           0.00   15         2   1  ...
# 37       1      0       39           0.00   15       -39   0  ...
# 38       2      5        6           0.00   49        -1   3  ...
# 39       1      6        1           0.00   25         5   3  ...
# 40       2     51        2           0.00   27        49  11  ...
# 41       1      3        3           0.00   24         0   6  ...
# 42       2      2        2           0.00   17         0   2  ...
# 43       1      0       86           0.00   15       -86   0  ...
# 44       2      2       18           0.50   50       -16   6  ...
# 45       2      2        4           0.00   49        -2   5  ...
# 46       1      0       32           0.00   25       -32   0  ...
# 47       2      4       27           0.00   49       -23   5  ...
# 48       1      0       43           0.00   17       -43   2  ...
# 49       2     41       12           0.00   17        29  23  ...
# 50       1      0       40           0.00   15       -40   0  ...
# 51       4     23       58           0.38   32       -35  13  ...
# 52       2     28        8           0.00   17        20   6  ...
# 53       1      0       85           0.00   15       -85   0  ...
# 54       1      0       88           0.00   17       -88   4  ...
# 55       3     14       14           0.67   54         0   4  ...
# 56       1      0       81           0.00   25       -81   4  ...
# 0        8     82       36           0.38   23        46   4  ...
# 1        2     35       36           0.00    8        -1   4  ...
# 2        1      0      117           0.00    7      -117   5  ...
#
#    assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# 0              19                 0           19               4
# 1               8                 4            8               0
# 2               1                 0            1               0
# 3               1                 0            1               0
# 4               1                 0            1               0
# 5               1                 0            2               0
# 6               1                 0            1               0
# 7               0                 0            0               0
# 8               0                 0            1              -1
# 9               0                 0            0               0
# 10              5                 1            5               2
# 11             84                13           83               1
# 12              1                 0            1               0
# 13              0                 0            0               0
# 14              1                 0            2               0
# 15              0                 0            1               0
# 16              6                 0            5               3
# 17              0                 0            1              -1
# 18             34                18           25               3
# 19              4                 1            4               1
# 20              0                 0            0               0
# 21              0                 0            0               0
# 22              1                 0            3               0
# 23              1                 0            1               0
# 24              0                 0            0               0
# 25              1                 0            2               0
# 26              0                 0            0               0
# 27              1                 0            1               0
# 28              0                 0            0               0
# 29              0                 0            0               0
# ..            ...               ...          ...             ...
# 30             20                 1           18               4
# 31              5                 5            5               0
# 32             16                 0           16               0
# 33              1                 0            1              -1
# 34              0                 0            0              -1
# 35             11                 0            7               1
# 36              0                 0            0              -1
# 37              0                 0            0              -1
# 38              5                 0            5               0
# 39              3                 0            3               1
# 40             21                 0           21               4
# 41             10                 1           10               0
# 42              8                 7            6               1
# 43              4                 0            4               0
# 44             12                 0           12               0
# 45              4                 1            4               1
# 46              4                 0            4              -1
# 47              4                 2            4               1
# 48              2                 0            2               0
# 49             95                16           86               3
# 50              0                 0            0               0
# 51             45                 3           35               3
# 52             12                 8           11               3
# 53              4                 0            4               0
# 54             10                 3           10               0
# 55              2                 0            3               2
# 56              6                 2            6               0
# 0               7                 0            7               1
# 1              11                 3           10               4
# 2              14                 1           12               3
#
#    anonymousClassesQty subClassesQty lambdasQty uniqueWordsQty modifiers  \
# 0                    0             0          0             76         1
# 1                    0             0          0             36         1
# 2                    0             0          0             15         1
# 3                    0             0          0             13         1
# 4                    0             0          0             15         1
# 5                    0             0          0             30         1
# 6                    0             0          0             26         1
# 7                    0             0          0             20         1
# 8                    0             0          0              4         1
# 9                    0             0          0             20         1
# 10                   0             0          0             32         1
# 11                   0             0          0            138         1
# 12                   0             0          0             15         1
# 13                   0             0          0              6         1
# 14                   0             0          0             13         1
# 15                   0             0          0              9         1
# 16                   0             2          0             79        21
# 17                   0             0          0              4         1
# 18                   0             0          0            102        17
# 19                   0             0          0             29         1
# 20                   0             0          0             20         1
# 21                   0             0          0             20         1
# 22                   0             0          0             18         1
# 23                   0             0          0             25         1
# 24                   0             0          0             20         1
# 25                   0             0          0             13         1
# 26                   0             0          0             20         1
# 27                   0             0          0             15         1
# 28                   0             0          0              6         1
# 29                   0             0          0              6         1
# ..                 ...           ...        ...            ...       ...
# 30                   0             0          0             47         1
# 31                   0             0          0             33      1025
# 32                   0             0          0             38         1
# 33                   0             0          0             18         1
# 34                   0             0          0             41         1
# 35                   0             0          0             24         1
# 36                   0             0          0             25         1
# 37                   0             0          0             16         1
# 38                   0             0          0             43         1
# 39                   0             0          0             18         1
# 40                   4            -2          0             65        -1
# 41                   0             0          0             45         1
# 42                   0             0          0             33         1
# 43                   0             0          0             21         1
# 44                   0             0          0             58         1
# 45                   0             0          0             19         1
# 46                   0             0          0             21         1
# 47                   0             0          0             44         1
# 48                   0             0          0             16         1
# 49                   0             0          0            146         1
# 50                   0             0          0             11         1
# 51                   0             1          0            159         9
# 52                   0             0          0             43         1
# 53                   0             0          0             21         1
# 54                   0             0          0             52         1
# 55                   0             0          0             27         1
# 56                   0             0          0             53         1
# 0                    0             0          0             51         1
# 1                    0             0          0             76         1
# 2                    0             0          0            100         1
#
#           time
# 0   2018-09-16
# 1   2018-09-16
# 2   2018-09-16
# 3   2018-09-16
# 4   2018-09-16
# 5   2018-09-16
# 6   2018-09-16
# 7   2018-09-16
# 8   2018-09-16
# 9   2018-09-16
# 10  2018-09-16
# 11  2018-09-16
# 12  2018-09-16
# 13  2018-09-16
# 14  2018-09-16
# 15  2018-09-16
# 16  2018-09-16
# 17  2018-09-16
# 18  2018-09-16
# 19  2018-09-16
# 20  2018-09-16
# 21  2018-09-16
# 22  2018-09-16
# 23  2018-09-16
# 24  2018-09-16
# 25  2018-09-16
# 26  2018-09-16
# 27  2018-09-16
# 28  2018-09-16
# 29  2018-09-16
# ..         ...
# 30  2004-08-14
# 31  2004-08-14
# 32  2004-08-14
# 33  2004-08-14
# 34  2004-08-14
# 35  2004-08-14
# 36  2004-08-14
# 37  2004-08-14
# 38  2004-08-14
# 39  2004-08-14
# 40  2004-08-14
# 41  2004-08-14
# 42  2004-08-14
# 43  2004-08-14
# 44  2004-08-14
# 45  2004-08-14
# 46  2004-08-14
# 47  2004-08-14
# 48  2004-08-14
# 49  2004-08-14
# 50  2004-08-14
# 51  2004-08-14
# 52  2004-08-14
# 53  2004-08-14
# 54  2004-08-14
# 55  2004-08-14
# 56  2004-08-14
# 0   2004-05-28
# 1   2004-05-28
# 2   2004-05-28
#
# [7689 rows x 50 columns]>

# %% [markdown]
# # Change Metrics
# ### Let's see what affects the net churn of files
# ### Which types of files have net churn above and below the mean net churn?

# %%
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

import psutil
cores = psutil.cpu_count()
estimators = 100

x = metricsDataMaven['data'].drop(['netchurn', 'added', 'deleted', 'entity', 'time'],axis=1)
y = np.array(metricsDataMaven['data']['loc'])

print "Decision Tree"
dt = DecisionTreeClassifier(max_depth=None, min_samples_split=2, random_state=0)
scoresDT = cross_val_score(dt, x, y)
print("Accuracy: %0.2f (+/- %0.2f)" % (scoresDT.mean(), scoresDT.std() * 2))
# Out:
# Decision Tree
# Accuracy: 0.92 (+/- 0.10)

# %%
# We split the data into 5 equally-sized groups, 
# then perform cross-validation while gradually adding these groups to the training set

# i.e. the train-test splits are with groups of size:
# 1-4, 2-3, 3-2, 4-1

# We omit visualization of decision trees to save space,
# but they can be shown with visualize=True as above
folds = 5

from sklearn.tree import DecisionTreeRegressor
modelInstance = DecisionTreeRegressor(max_leaf_nodes=16)
modelSimpler = DecisionTreeRegressor(max_leaf_nodes=8)
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], folds, 'netchurn', modelInstance, modelSimpler, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 0.328184
#       name  importance
# 4  deleted    0.506010
# 3    added    0.385737
# Model.score: 0.665100
#       name  importance
# 4  deleted    0.716070
# 3    added    0.261963
# Model.score: 0.864758
#       name  importance
# 4  deleted    0.656892
# Model.score: 0.890501
#       name  importance
# 4  deleted    0.824072
# Model.score: 0.364833
#       name  importance
# 1  deleted    0.549204
# 0    added    0.450796
# Model.score: 0.633886
#       name  importance
# 1  deleted    0.731493
# 0    added    0.268507
# Model.score: 0.845082
#       name  importance
# 1  deleted     0.86986
# Model.score: 0.774369
#       name  importance
# 1  deleted    0.878853

# %% [markdown]
# ### Some observations:
# - The model has very good Precision, Recall and F1-Score: net churn above/below the mean is classified very well by this model
# - ROC area under curve is very high: very little compromise between false negative rate and false positive rate
# - The model says that the features influencing net churn are (strongest to weakest):
#     - Number of lines added
#     - Number of lines deleted
# - The 'net churn below the mean' class is over-represented in our data (3 times as many samples as the other class)
#     - However, the model still performs well without any steps taken to address class imbalance (e.g. under/over-sampling)
# - Interpretation of the visualized decision tree is straightforward:
#     - 63% of samples were files with less than 34 lines added
#         - These samples had net churn less than the mean
#         - Some of these may be very stable files (over the history of the project)
#     - The files with net churn greater than the mean had more than 108 lines added
#     - Within this group, there are several subgroups with varying levels of churn

# %% [markdown]
# ### Each of the subsets still exhibits class imbalance (but not with the same ratio)
# ### In particular, the 2nd train-test split has the most balanced classes (2:1) among the five splits
#
# ### We still see very good performance, and the same features are important throughout
# ### How far can we go? Let's cross-validate on every sampled time!

# %%
folds = metricsDataMaven['times'] # This is an attribute of the measured data set: the number of time points measured
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], folds, 'netchurn', modelInstance, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 1.000000
#               name  importance
# 4          deleted    0.691824
# 15  privateMethods    0.308176
# Model.score: -0.008065
#               name  importance
# 4          deleted    0.592672
# 15  privateMethods    0.407328
# Model.score: 0.000000
#              name  importance
# 3           added    0.613590
# 14  publicMethods    0.336134
# Model.score: 0.124650
#       name  importance
# 4  deleted    0.565217
# 3    added    0.434783
# Model.score: -0.041667
#       name  importance
# 3    added    0.464330
# 4  deleted    0.395989
# Model.score: 1.000000
#       name  importance
# 4  deleted    0.514295
# 3    added    0.368039
# Model.score: 0.092010
#       name  importance
# 4  deleted    0.492759
# 3    added    0.381241
# Model.score: 1.000000
#       name  importance
# 4  deleted    0.504246
# 3    added    0.388289
# Model.score: 1.000000
#       name  importance
# 4  deleted    0.544503
# 3    added    0.357112
# Model.score: 0.813803
#       name  importance
# 4  deleted    0.512352
# 3    added    0.381290
# Model.score: 0.791667
#       name  importance
# 4  deleted    0.544287
# 3    added    0.344789
# Model.score: 1.000000
#       name  importance
# 4  deleted    0.517069
# 3    added    0.368429
# Model.score: -0.024590
#       name  importance
# 4  deleted    0.521119
# 3    added    0.419381
# Model.score: 1.000000
#       name  importance
# 4  deleted    0.466747
# 3    added    0.444303
# Model.score: 0.791667
#       name  importance
# 4  deleted     0.47058
# 3    added     0.44301
# Model.score: 0.570918
#       name  importance
# 4  deleted    0.459652
# 3    added    0.433450
# Model.score: 0.485066
#       name  importance
# 4  deleted    0.450906
# 3    added    0.415984
# Model.score: 0.491742
#       name  importance
# 4  deleted    0.504406
# 3    added    0.415483
# Model.score: 0.570920
#       name  importance
# 4  deleted    0.492793
# 3    added    0.412323
# Model.score: 0.956104
#       name  importance
# 4  deleted    0.501949
# 3    added    0.446314
# Model.score: 0.722470
#       name  importance
# 4  deleted    0.485720
# 3    added    0.444611
# Model.score: 0.790984
#       name  importance
# 4  deleted    0.493540
# 3    added    0.454171
# Model.score: 0.763708
#       name  importance
# 4  deleted    0.480116
# 3    added    0.468741
# Model.score: 0.657626
#       name  importance
# 4  deleted    0.514678
# 3    added    0.449161
# Model.score: 0.776150
#       name  importance
# 4  deleted    0.523333
# 3    added    0.442803
# Model.score: 0.930425
#       name  importance
# 4  deleted    0.532992
# 3    added    0.433681
# Model.score: 0.859820
#       name  importance
# 4  deleted    0.543477
# 3    added    0.440169
# Model.score: 0.913357
#       name  importance
# 4  deleted    0.590100
# 3    added    0.384759
# Model.score: 0.821415
#       name  importance
# 4  deleted    0.604949
# 3    added    0.375003
# Model.score: 0.946430
#       name  importance
# 4  deleted    0.633697
# 3    added    0.354005
# Model.score: 0.869441
#       name  importance
# 4  deleted    0.634670
# 3    added    0.353427
# Model.score: 0.675809
#       name  importance
# 4  deleted    0.647223
# 3    added    0.345797
# Model.score: 0.642526
#       name  importance
# 4  deleted    0.679798
# 3    added    0.316022
# Model.score: 0.827877
#       name  importance
# 4  deleted    0.669654
# 3    added    0.317470
# Model.score: 0.957543
#       name  importance
# 4  deleted    0.669915
# 3    added    0.317544
# Model.score: 0.997861
#       name  importance
# 4  deleted    0.688294
# 3    added    0.303919
# Model.score: 0.999826
#       name  importance
# 4  deleted    0.689908
# 3    added    0.302878
# Model.score: 0.999842
#       name  importance
# 4  deleted    0.692286
# 3    added    0.300593
# Model.score: 0.936027
#       name  importance
# 4  deleted    0.694766
# 3    added    0.302131
# Model.score: 0.771244
#       name  importance
# 4  deleted    0.697720
# 3    added    0.296352
# Model.score: 0.999754
#       name  importance
# 4  deleted    0.699627
# 3    added    0.294567
# Model.score: 0.998575
#       name  importance
# 4  deleted    0.700155
# 3    added    0.290919
# Model.score: 0.900986
#       name  importance
# 4  deleted    0.736743
# 3    added    0.252169
# Model.score: 0.905081
#       name  importance
# 4  deleted    0.745358
# 3    added    0.252337
# Model.score: 0.946482
#       name  importance
# 4  deleted    0.745761
# 3    added    0.245557
# Model.score: 0.999133
#       name  importance
# 4  deleted    0.750444
# 3    added    0.241549
# Model.score: 0.723641
#       name  importance
# 4  deleted    0.760146
# 3    added    0.234594
# Model.score: 0.894898
#       name  importance
# 4  deleted    0.757034
# 3    added    0.235426
# Model.score: 0.902243
#       name  importance
# 4  deleted    0.753525
# 3    added    0.241162
# Model.score: 0.446304
#       name  importance
# 4  deleted    0.749644
# 3    added    0.245049
# Model.score: 0.965153
#       name  importance
# 4  deleted    0.741671
# 3    added    0.253059
# Model.score: 0.786976
#       name  importance
# 4  deleted    0.737449
# 3    added    0.255300
# Model.score: 0.750778
#       name  importance
# 4  deleted    0.738085
# 3    added    0.256833
# Model.score: 0.884129
#       name  importance
# 4  deleted    0.727445
# 3    added    0.267604
# Model.score: 0.831259
#       name  importance
# 4  deleted    0.729530
# 3    added    0.265562
# Model.score: 0.839619
#       name  importance
# 4  deleted    0.727643
# 3    added    0.267460
# Model.score: 0.929392
#       name  importance
# 4  deleted    0.713706
# 3    added    0.279457
# Model.score: 0.749052
#       name  importance
# 4  deleted    0.719563
# 3    added    0.275033
# Model.score: 0.966927
#       name  importance
# 4  deleted    0.701133
# 3    added    0.298867
# Model.score: 0.952259
#       name  importance
# 4  deleted     0.70047
# 3    added     0.29953
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.691824
# 0    added    0.308176
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.592672
# 0    added    0.407328
# Model.score: 1.000000
#       name  importance
# 0    added     0.61359
# 1  deleted     0.38641
# Model.score: 0.124650
#       name  importance
# 1  deleted    0.565217
# 0    added    0.434783
# Model.score: -0.041667
#       name  importance
# 0    added    0.559963
# 1  deleted    0.440037
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.520606
# 0    added    0.479394
# Model.score: 0.546005
#       name  importance
# 1  deleted     0.50177
# 0    added     0.49823
# Model.score: 0.491870
#       name  importance
# 1  deleted    0.518355
# 0    added    0.481645
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.585811
# 0    added    0.414189
# Model.score: 0.813803
#       name  importance
# 1  deleted    0.541602
# 0    added    0.458398
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.575494
# 0    added    0.424506
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.571735
# 0    added    0.428265
# Model.score: -0.024590
#       name  importance
# 1  deleted    0.535433
# 0    added    0.464567
# Model.score: 1.000000
#       name  importance
# 1  deleted     0.52142
# 0    added     0.47858
# Model.score: 1.000000
#       name  importance
# 1  deleted    0.515781
# 0    added    0.484219
# Model.score: 0.742445
#       name  importance
# 1  deleted    0.503739
# 0    added    0.496261
# Model.score: 0.747211
#       name  importance
# 0    added    0.505607
# 1  deleted    0.494393
# Model.score: 0.999548
#       name  importance
# 1  deleted    0.531012
# 0    added    0.468988
# Model.score: 0.787038
#       name  importance
# 1  deleted    0.521942
# 0    added    0.478058
# Model.score: 0.999715
#       name  importance
# 1  deleted    0.518506
# 0    added    0.481494
# Model.score: 0.740264
#       name  importance
# 1  deleted    0.507154
# 0    added    0.492846
# Model.score: 0.810203
#       name  importance
# 1  deleted    0.519057
# 0    added    0.480943
# Model.score: 0.814437
#       name  importance
# 1  deleted    0.505308
# 0    added    0.494692
# Model.score: 0.714480
#       name  importance
# 1  deleted    0.521362
# 0    added    0.478638
# Model.score: 0.910067
#       name  importance
# 1  deleted     0.51074
# 0    added     0.48926
# Model.score: 0.926778
#       name  importance
# 1  deleted    0.551109
# 0    added    0.448891
# Model.score: 0.870969
#       name  importance
# 1  deleted    0.549573
# 0    added    0.450427
# Model.score: 0.965342
#       name  importance
# 1  deleted    0.605582
# 0    added    0.394418
# Model.score: 0.863442
#       name  importance
# 1  deleted    0.616036
# 0    added    0.383964
# Model.score: 0.902324
#       name  importance
# 1  deleted    0.640227
# 0    added    0.359773
# Model.score: 0.900072
#       name  importance
# 1  deleted    0.640479
# 0    added    0.359521
# Model.score: 0.726726
#       name  importance
# 1  deleted    0.651147
# 0    added    0.348853
# Model.score: 0.654290
#       name  importance
# 1  deleted    0.679351
# 0    added    0.320649
# Model.score: 0.834339
#       name  importance
# 1  deleted    0.667812
# 0    added    0.332188
# Model.score: 0.997937
#       name  importance
# 1  deleted    0.667951
# 0    added    0.332049
# Model.score: 0.998648
#       name  importance
# 1  deleted    0.683575
# 0    added    0.316425
# Model.score: 0.999600
#       name  importance
# 1  deleted    0.685507
# 0    added    0.314493
# Model.score: 0.999842
#       name  importance
# 1  deleted    0.687928
# 0    added    0.312072
# Model.score: 0.960445
#       name  importance
# 1  deleted    0.690444
# 0    added    0.309556
# Model.score: 0.771244
#       name  importance
# 1  deleted    0.699743
# 0    added    0.300257
# Model.score: 0.612713
#       name  importance
# 1  deleted    0.703693
# 0    added    0.296307
# Model.score: 0.993018
#       name  importance
# 1  deleted    0.698529
# 0    added    0.301471
# Model.score: 0.999105
#       name  importance
# 1  deleted    0.734926
# 0    added    0.265074
# Model.score: 0.907058
#       name  importance
# 1  deleted    0.740688
# 0    added    0.259312
# Model.score: 0.946482
#       name  importance
# 1  deleted    0.743069
# 0    added    0.256931
# Model.score: 0.999180
#       name  importance
# 1  deleted    0.747949
# 0    added    0.252051
# Model.score: 0.678573
#       name  importance
# 1  deleted    0.755487
# 0    added    0.244513
# Model.score: 0.895575
#       name  importance
# 1  deleted    0.755125
# 0    added    0.244875
# Model.score: 0.902247
#       name  importance
# 1  deleted     0.75574
# 0    added     0.24426
# Model.score: 0.382994
#       name  importance
# 1  deleted    0.745847
# 0    added    0.254153
# Model.score: 0.999003
#       name  importance
# 1  deleted    0.737987
# 0    added    0.262013
# Model.score: 0.886330
#       name  importance
# 1  deleted    0.736173
# 0    added    0.263827
# Model.score: 0.744166
#       name  importance
# 1  deleted    0.729978
# 0    added    0.270022
# Model.score: 0.885730
#       name  importance
# 1  deleted     0.72265
# 0    added     0.27735
# Model.score: 0.834157
#       name  importance
# 1  deleted    0.721523
# 0    added    0.278477
# Model.score: 0.994371
#       name  importance
# 1  deleted    0.721142
# 0    added    0.278858
# Model.score: 0.900781
#       name  importance
# 1  deleted    0.718175
# 0    added    0.281825
# Model.score: 0.806042
#       name  importance
# 1  deleted    0.714684
# 0    added    0.285316
# Model.score: 0.966927
#       name  importance
# 1  deleted    0.701133
# 0    added    0.298867
# Model.score: 0.952259
#       name  importance
# 1  deleted     0.70047
# 0    added     0.29953

# %% [markdown]
# ### Results of this step are omitted for printing. However, the large cross-validation can be run to see them.

# %% [markdown]
# ### The individual data sets used for training and testing are quite small and imbalanced.
#
# ### Many of the same relationships still show up.
#
# ### Why is 'added' a much more important factor than 'deleted'?

# %%
print "Mean", metricsDataMaven['data']['netchurn'].mean()
print "Variance", metricsDataMaven['data']['netchurn'].var()
print "Standard deviation", metricsDataMaven['data']['netchurn'].std()
print "Max", metricsDataMaven['data']['netchurn'].max()
print "Min", metricsDataMaven['data']['netchurn'].min()
# Out:
# Mean -19.92131616595136
# Variance 14157.13337620713
# Standard deviation 118.9837525723875
# Max 650
# Min -3332

# %% [markdown]
# ### This codebase is *growing* in general (more added than deleted)
#
# ### Some files must experience more churn than others. We know from some of the motivating literature that defects can be correlated with large pre-release churn.
#
# ### Let's make some categories of binned churn data and classify them

# %%
churnBinnedCategories = ['churnLow','churnMedium','churnHigh','churnHighest']
dataSetUpdated = toolkit.utilities.addBinnedResponseCategory(metricsDataMaven['data'], 'netchurn', churnBinnedCategories)

# %%
from sklearn.tree import DecisionTreeClassifier
modelInstance = DecisionTreeClassifier(max_leaf_nodes=8, criterion='entropy')
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMedium', 'churnHigh', 'churnHighest']
# Model.score: 0.995576
# accuracy_score: 0.995576
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.43      0.86      0.57         7
#           2       0.92      0.90      0.91        93
#           3       1.00      1.00      1.00      3742
#
# avg / total       1.00      1.00      1.00      3843
#
# roc_auc_score: 0.841876
#       name  importance
# 4  deleted    0.827502
# Model.score: 0.817335
# accuracy_score: 0.995316
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.43      0.86      0.57         7
#           2       0.92      0.90      0.91        93
#           3       1.00      1.00      1.00      3742
#
# avg / total       1.00      1.00      1.00      3843
#
# roc_auc_score: 0.840605
#       name  importance
# 2  deleted    0.622659
# 1    added    0.199119

# %% [markdown]
# ### Now we're seeing something interesting. The vast majority of the files exhibit very low amounts of churn. A select few files receive most of the lines added/deleted. Does the class imbalance impact the validity of this model? Let's try more cross-validation to see.

# %%
folds = 3
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, folds, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMedium', 'churnHigh']
# Model.score: 0.995316
# accuracy_score: 0.995316
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.75      0.38      0.50        16
#           2       1.00      1.00      1.00      2545
#
# avg / total       0.99      1.00      0.99      2562
#
# roc_auc_score: 0.630931
#       name  importance
# 4  deleted         1.0
# Model.score: 0.999219
# accuracy_score: 0.999219
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      0.93      0.96        29
#           2       1.00      1.00      1.00      2533
#
# avg / total       1.00      1.00      1.00      2562
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 4  deleted     0.88754
# Model.score: 0.289665
# accuracy_score: 0.995316
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.75      0.38      0.50        16
#           2       1.00      1.00      1.00      2545
#
# avg / total       0.99      1.00      0.99      2562
#
# roc_auc_score: 0.630931
#       name  importance
# 2  deleted         1.0
# Model.score: 0.720980
# accuracy_score: 0.996877
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      0.72      0.84        29
#           2       1.00      1.00      1.00      2533
#
# avg / total       1.00      1.00      1.00      2562
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 2  deleted    0.800389

# %% [markdown]
# ### Let's look at this from another point of view. What characterises the files which have the most lines added?

# %%
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], 2, 'added', modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.936248
# accuracy_score: 0.936248
#              precision    recall  f1-score   support
#
#           0       0.94      0.97      0.96      2960
#           1       0.90      0.81      0.85       883
#
# avg / total       0.94      0.94      0.93      3843
#
# roc_auc_score: 0.891466
#        name  importance
# 6  netchurn    0.644053
# 3   deleted    0.286140
# Model.score: 0.694819
#        name  importance
# 2  netchurn    0.734325

# %% [markdown]
# ### Net churn and deleted lines are strongly related. What do we find if we're not allowed to use these in our decision tree?

# %%
alteredData = metricsDataMaven['data'].drop(['netchurn','deleted'], axis=1)
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData, 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.859225
# accuracy_score: 0.859225
#              precision    recall  f1-score   support
#
#           0       0.86      0.97      0.91      2960
#           1       0.83      0.49      0.61       883
#
# avg / total       0.86      0.86      0.84      3843
#
# roc_auc_score: 0.728623
#      name  importance
# 2  n-revs    0.907082
# Model.score: 0.435172
#      name  importance
# 1  n-revs    0.938817

# %% [markdown]
# ### The model uses n-revs as the most important feature, but it does not classify '# lines added above the mean' very well

# %%
alteredData2 = metricsDataMaven['data'].drop(['netchurn','deleted','n-revs'], axis=1)
addedModel2 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData2, 3, 'added', modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.826698
# accuracy_score: 0.826698
#              precision    recall  f1-score   support
#
#           0       0.84      0.97      0.90      2043
#           1       0.69      0.26      0.38       519
#
# avg / total       0.81      0.83      0.79      2562
#
# roc_auc_score: 0.614655
#               name  importance
# 42  uniqueWordsQty    0.446906
# 2    fractal-value    0.215856
# Model.score: 0.822795
# accuracy_score: 0.822795
#              precision    recall  f1-score   support
#
#           0       0.85      0.93      0.89      1930
#           1       0.70      0.49      0.58       632
#
# avg / total       0.81      0.82      0.81      2562
#
# roc_auc_score: 0.711588
#          name  importance
# 1   n-authors    0.468265
# 27        loc    0.200639
# Model.score: 0.030814
#         name  importance
# 3        rfc    0.490536
# 1  n-authors    0.284736
# Model.score: 0.242549
#         name  importance
# 3        rfc    0.505735
# 1  n-authors    0.320394

# %% [markdown]
# ### n-authors has similar problems with identifying the minority class

# %%
alteredData3 = metricsDataMaven['data'].drop(['netchurn','deleted','n-revs','n-authors'], axis=1)
addedModel3 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData3, 3, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.826698
# accuracy_score: 0.826698
#              precision    recall  f1-score   support
#
#           0       0.84      0.97      0.90      2043
#           1       0.69      0.26      0.38       519
#
# avg / total       0.81      0.83      0.79      2562
#
# roc_auc_score: 0.614655
#               name  importance
# 41  uniqueWordsQty    0.446906
# 1    fractal-value    0.257677
# Model.score: 0.822795
# accuracy_score: 0.822795
#              precision    recall  f1-score   support
#
#           0       0.85      0.93      0.89      1930
#           1       0.70      0.49      0.58       632
#
# avg / total       0.81      0.82      0.81      2562
#
# roc_auc_score: 0.711588
#              name  importance
# 1   fractal-value    0.525249
# 26            loc    0.200639
# Model.score: 0.032129
#             name  importance
# 1            rfc    0.532270
# 0  fractal-value    0.353595
# Model.score: 0.261244
#             name  importance
# 1            rfc    0.507863
# 0  fractal-value    0.451252

# %% [markdown]
# ### fractal-value is derived from n-revs and n-authors
#
# ### Let's get rid of it and build a regression model for nline

# %% [markdown]
# # Java Code Metrics

# %% [markdown]
# ### This model will predict the CBO (Coupling between objects)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=64)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=32)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 5, 'cbo', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was cbo
# Model.score: 0.779736
#    name  importance
# 10  rfc    0.806984
# Model.score: 0.635313
#    name  importance
# 10  rfc    0.823932
# Model.score: 0.558921
#    name  importance
# 10  rfc     0.79385
# Model.score: 0.741696
#    name  importance
# 10  rfc    0.780346
# Model.score: 0.814343
#   name  importance
# 3  rfc     0.84311
# Model.score: 0.666348
#   name  importance
# 3  rfc    0.860317
# Model.score: 0.472119
#   name  importance
# 3  rfc    0.833973
# Model.score: 0.721795
#   name  importance
# 3  rfc    0.816154

# %% [markdown]
# ### We see that the most important feature for predicting coupling between objects is RFC (Response for a Class). The RFC counts the number of unique method invocations in a class.

# %% [markdown]
# ### It seems that the number of unique method invocations in a class is directly related to coupling between objects. What happens if we drop RFC from our dataframe?

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=64)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=32)
alteredData4 = metricsDataMaven['data'].drop(['rfc'],axis=1)
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 5, 'cbo', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was cbo
# Model.score: 0.794720
#             name  importance
# 39  variablesQty    0.584536
# Model.score: 0.610500
#             name  importance
# 39  variablesQty    0.650013
# Model.score: 0.527867
#             name  importance
# 39  variablesQty    0.534033
# Model.score: 0.654226
#             name  importance
# 39  variablesQty    0.590394
# Model.score: 0.793977
#             name  importance
# 22  variablesQty    0.627931
# Model.score: 0.623343
#             name  importance
# 22  variablesQty    0.686932
# Model.score: 0.519308
#             name  importance
# 22  variablesQty     0.56433
# Model.score: 0.599022
#             name  importance
# 22  variablesQty    0.627657

# %% [markdown]
# ### The second most important feature for predicting coupling between objects appears to be the total number of variables in a class.

# %% [markdown]
# ### This model will predict the LCOM (Lack of Cohesion of Methods)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=16)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'lcom', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was lcom
# Model.score: 0.737535
#             name  importance
# 12  totalMethods    0.968387
# Model.score: 0.696429
#            name  importance
# 0  totalMethods    0.983405

# %% [markdown]
# ### We see that the most important feature for predicting lack of cohesion of methods (LCOM) is the total number of methods in a class.
#
# ### What happens if we drop 'totalMethods' from our dataframe?

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=16)
alteredData4 = metricsDataMaven['data'].drop(['totalMethods'],axis=1)
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'lcom', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was lcom
# Model.score: 0.620665
#   name  importance
# 9  wmc    0.729163
# Model.score: 0.682443
#   name  importance
# 0  wmc    0.731014

# %% [markdown]
# ### It appears that the second most important feature for predicting lack of cohesion of methods is weight method class (WMC) or McCabe's complexity. This makes sense since it is a measure of the number of branch instructions in a class.

# %% [markdown]
# ### This model predicts the size of files in terms of lines of code (loc)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=32)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=16)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'loc', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was loc
# Model.score: 0.922144
#               name  importance
# 38  assignmentsQty    0.493466
# 40    variablesQty    0.191737
# Model.score: 0.843970
#               name  importance
# 10  assignmentsQty    0.498693
# 12    variablesQty    0.194699

# %% [markdown]
# ### The most important feature for predicting size of a file by lines of code is the total number of assignments.

# %% [markdown]
# ### This model predicts the WMC (Weight Method Class) or McCabe's complexity.

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=16)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 3, 'wmc', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was wmc
# Model.score: 0.893683
#             name  importance
# 12  totalMethods    0.499192
# 30           loc    0.383173
# Model.score: 0.864437
#             name  importance
# 30           loc    0.614904
# 12  totalMethods    0.263566
# Model.score: 0.871853
#              name  importance
# 5  comparisonsQty    0.532544
# 3             loc    0.380150
# Model.score: 0.864437
#            name  importance
# 3           loc    0.614904
# 0  totalMethods    0.263566

# %% [markdown]
# ### We can see there is a moderate correlation between WMC and the total number of methods.

# %%
# We use the Spearman measure of rank correlation
metricsDataMaven['data']['totalMethods'].corr(metricsDataMaven['data']['wmc'], method='spearman')
# Out:
# 0.4545093209163478

# %% [markdown]
# ### In this case study, we have used the toolkit to do the following:
# - Gather the Maven dataset
# - Create regression models of net churn: above and below the mean, in 3 binned categories (low, medium, high)
# - Create regression models to analyze coupling between objects, lack of cohesion of methods, and weighted method class.
