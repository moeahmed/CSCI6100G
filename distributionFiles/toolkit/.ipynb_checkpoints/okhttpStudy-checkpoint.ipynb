# %%
import toolkit

# %% [markdown]
# ### First, we gather the dataset. This is a history of static code metrics (Java, C and indentation) and change metrics for our project.

# %%
# Used to indicate where the data should be gathered and stored
rootDirectory = '../dataSets/okhttpStudy/'

# Call gatherTimeMetrics and measure Java, Indent and Change metrics 
# on .java files from the git project's repository
#%debug
metricsData = toolkit.data.gatherTimeMetrics(rootDirectory, 'https://github.com/square/okhttp.git', rootDirectory+'okhttp/', '*/*.java *.java', ['java'], skipEvery=50)
# Out:
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)
# ('ck metrics output successful', 0)

# %%
metricsData['data']
# Out:
#                                                entity  age-months  n-authors  \
# 0   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 1   okhttp-sse/src/test/java/okhttp3/internal/sse/...           0          2
# 2   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 3         okhttp/src/test/java/okhttp3/CacheTest.java           1          3
# 4   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           1          2
# 5   okhttp/src/test/java/okhttp3/EventListenerTest...           1          3
# 6   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           1          2
# 7          okhttp/src/test/java/okhttp3/CallTest.java           1          4
# 8    okhttp/src/test/java/okhttp3/DispatcherTest.java           1          2
# 9   okhttp/src/test/java/okhttp3/internal/connecti...           1          3
# 10       okhttp/src/test/java/okhttp3/DuplexTest.java           1          2
# 11      okhttp/src/test/java/okhttp3/CookiesTest.java           2          1
# 12  okhttp/src/test/java/okhttp3/InterceptorTest.java           2          1
# 13  okhttp/src/test/java/okhttp3/URLConnectionTest...           2          1
# 14  okhttp/src/test/java/okhttp3/WholeOperationTim...           2          2
# 15  okhttp/src/test/java/okhttp3/internal/tls/Clie...           2          2
# 16  okhttp/src/test/java/okhttp3/ConnectionReuseTe...           2          1
# 17  okhttp-testing-support/src/main/java/okhttp3/T...           3          1
# 0   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           4          2
# 1   okhttp/src/test/java/okhttp3/EventListenerTest...           4          2
# 2   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 3   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           4          2
# 4   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 5   okhttp/src/test/java/okhttp3/internal/http2/Ht...           4          3
# 6   okhttp-logging-interceptor/src/test/java/okhtt...           4          3
# 7   okhttp/src/test/java/okhttp3/URLConnectionTest...           4          3
# 8   okhttp/src/test/java/okhttp3/RecordingEventLis...           4          1
# 9        okhttp/src/test/java/okhttp3/DuplexTest.java           4          2
# 10  okhttp/src/test/java/okhttp3/internal/platform...           5          1
# 11  okhttp/src/test/java/okhttp3/internal/ws/WebSo...           5          2
# ..                                                ...         ...        ...
# 34  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 35  src/main/java/com/squareup/okhttp/internal/net...          83          1
# 36  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 37  src/test/java/com/squareup/okhttp/internal/io/...          83          1
# 38  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 0   src/main/java/com/squareup/okhttp/OkHttpConnec...          84          1
# 1   src/main/java/libcore/net/http/HttpTransport.java          84          1
# 2   src/main/java/com/squareup/okhttp/OkHttpsConne...          84          2
# 3   src/main/java/libcore/util/ExtendedResponseCac...          84          2
# 4   src/main/java/libcore/net/http/HttpURLConnecti...          84          2
# 5   src/main/java/libcore/net/http/HttpResponseCac...          84          3
# 6   src/main/java/libcore/net/http/HttpsURLConnect...          84          2
# 7   src/test/java/libcore/net/http/URLConnectionTe...          84          3
# 8      src/main/java/libcore/net/http/HttpEngine.java          84          2
# 9   src/test/java/libcore/net/http/ExternalSpdyExa...          84          1
# 10   src/main/java/libcore/net/http/HeaderParser.java          85          2
# 11  src/main/java/libcore/net/http/RetryableOutput...          85          1
# 12  src/main/java/libcore/net/http/HttpConnection....          85          1
# 13  src/main/java/libcore/net/http/HttpConnectionP...          85          1
# 14      src/main/java/libcore/net/http/Challenge.java          85          1
# 15     src/main/java/libcore/net/http/RawHeaders.java          85          1
# 16     src/main/java/libcore/net/spdy/SpdyWriter.java          85          2
# 17            src/main/java/libcore/util/Libcore.java          85          1
# 18  src/main/java/libcore/net/spdy/SpdyConnection....          86          1
# 19     src/main/java/libcore/net/spdy/SpdyStream.java          86          1
# 20   src/test/java/libcore/net/spdy/MockSpdyPeer.java          86          1
# 21     src/main/java/libcore/net/spdy/SpdyServer.java          86          1
# 22     src/main/java/libcore/net/spdy/SpdyReader.java          86          1
# 23  src/test/java/libcore/net/spdy/SpdyConnectionT...          86          1
# 24  src/main/java/libcore/net/http/ResponseHeaders...          86          1
#
#     n-revs  added  deleted  fractal-value  soc  netchurn  cbo  ...  \
# 0        6     90       61           0.28    8        29   34  ...
# 1        2      3        8           0.50   12        -5   12  ...
# 2        6    128        6           0.44   14       122   86  ...
# 3        4     43        9           0.63    7        34   37  ...
# 4        2    105        7           0.50    6        98   20  ...
# 5        4      8       18           0.63   28       -10   68  ...
# 6        4     17       17           0.50   24         0   40  ...
# 7       10     95       19           0.64   32        76  118  ...
# 8        2      5        6           0.50   16        -1   16  ...
# 9        6     49       22           0.50    8        27   13  ...
# 10       3      5        5           0.44   23         0   27  ...
# 11       1      1        6           0.00   10        -5   15  ...
# 12       2     13       11           0.00   10         2   41  ...
# 13       1      1        2           0.00   10        -1  120  ...
# 14       2      6        7           0.50   10        -1   23  ...
# 15       2      5        0           0.50    9         5   14  ...
# 16       1      1        6           0.00   10        -5   18  ...
# 17       1     12        0           0.00    7        12    2  ...
# 0        4      3       18           0.38   40       -15   21  ...
# 1        6     44       28           0.44   81        16   68  ...
# 2        1      9        0           0.00    6         9   21  ...
# 3        5     34       25           0.48   47         9   37  ...
# 4        1      9        0           0.00    6         9   13  ...
# 5        8     58       56           0.59   68         2   86  ...
# 6        4     17        7           0.63   37        10   21  ...
# 7        9     37       28           0.64   84         9  120  ...
# 8        1     27        0           0.00    6        27  104  ...
# 9        3      8        8           0.44   42         0   27  ...
# 10       1      1        1           0.00   14         0    4  ...
# 11       3      5        4           0.44   27         1    8  ...
# ..     ...    ...      ...            ...  ...       ...  ...  ...
# 34       2      4       44           0.00   17       -40    1  ...
# 35       3     30        8           0.00   18        22    9  ...
# 36       2    252      270           0.00   15       -18   22  ...
# 37       1     61       87           0.00   12       -26    6  ...
# 38       1      5        4           0.00   12         1    2  ...
# 0        1      0      829           0.00   11      -829    3  ...
# 1        6     70      109           0.00   33       -39   40  ...
# 2        2      0      300           0.50   15      -300    2  ...
# 3        2      5        3           0.50   18         2    2  ...
# 4        8     84      116           0.22   42       -32   13  ...
# 5        6     43       45           0.50   24        -2   41  ...
# 6        4     31      104           0.38   27       -73   28  ...
# 7       14    563      216           0.26   55       347   45  ...
# 8        8     72       50           0.22   48        22   15  ...
# 9        1      3        3           0.00   11         0    2  ...
# 10       2      2       54           0.50   13       -52    4  ...
# 11       1      5        4           0.00    9         1    4  ...
# 12       6    323      326           0.00   32        -3   16  ...
# 13       2      3       10           0.00   13        -7    4  ...
# 14       1      0       40           0.00   11       -40    1  ...
# 15       4     76       33           0.00   28        43    2  ...
# 16       6     96       62           0.28   22        34    2  ...
# 17       3      5      153           0.00   14      -148    8  ...
# 18       9    452      343           0.00   34       109   18  ...
# 19       4    127       76           0.00   12        51   13  ...
# 20       4     79       20           0.00   19        59   10  ...
# 21       2     12        6           0.00    7         6    5  ...
# 22       7    119       74           0.00   29        45    6  ...
# 23       8    536      113           0.00   32       423    9  ...
# 24       1      2        1           0.00    7         1    9  ...
#
#    assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# 0             262                12          261               3
# 1              12                 3           10               0
# 2             231                 7          214               8
# 3             295               136          282               1
# 4              34                 0           32               1
# 5             154                11          141               5
# 6              89                 8           82               2
# 7             435                35          377              10
# 8              36                 0           36               2
# 9              28                 0           28               1
# 10             70                 0           64               2
# 11             63                 9           55               2
# 12            136                12          142               5
# 13            390                45          329               5
# 14             36                 1           36               3
# 15             41                 0           40               1
# 16             53                 0           48               1
# 17              5                 2            4               1
# 0              36                 0           32               1
# 1             155                11          141               5
# 2              11                 2           11               2
# 3              88                 8           81               2
# 4               7                 2            7               2
# 5             229                 7          214               8
# 6              13                22           11               1
# 7             390                45          329               5
# 8              35                 5           32               1
# 9              70                 0           64               2
# 10              1                 0            1               0
# 11             11                 1           11               2
# ..            ...               ...          ...             ...
# 34              0                 0            0               0
# 35             47                13           44               2
# 36            172                92          165               6
# 37             88                 8           67               2
# 38              5                 0            5               0
# 0              60                 6           50               2
# 1              72                 9           47              10
# 2              10                 0            6               1
# 3               0                 0            0              -1
# 4              39                 6           30               2
# 5              80                12           67              10
# 6              22                 1           16               3
# 7             196                21          191               1
# 8              65                 4           50               3
# 9               5                 1            5               1
# 10             27                 0           16               2
# 11              5                 3            2               1
# 12             47                14           33               4
# 13             17                 3           13               3
# 14              2                 2            2               0
# 15             65                29           43               4
# 16             14                12           20               1
# 17             28                10           19               3
# 18             48                 2           35               5
# 19             58                16           32               7
# 20             24                 0           21               4
# 21             17                 3           15               2
# 22             40                 7           33               4
# 23             21                 0           13               0
# 24             57                10           45               4
#
#    anonymousClassesQty subClassesQty lambdasQty uniqueWordsQty modifiers  \
# 0                    6            -2          0            391        24
# 1                    0             0          0             45        17
# 2                   22            -9          1            438        16
# 3                    6            -4          3            561        14
# 4                    2            -1          3            182        16
# 5                   12            -5          3            239        13
# 6                   14            -7          3            248        10
# 7                   52           -25          8            731         1
# 8                    0             0          4            120        17
# 9                    0             0          0             91        17
# 10                   2            -1          0            157        16
# 11                   4            -2          0            111        -1
# 12                   6            -2         31            208        24
# 13                  42           -22          1            781         6
# 14                   8            -4          0             97        13
# 15                   0             0          0             89        17
# 16                   0             0          1            145        17
# 17                   0             0          0             50        17
# 0                    2            -1          3            191        16
# 1                   12            -5          3            239        13
# 2                    6            -2          0            137        40
# 3                   14            -7          3            249        10
# 4                    0             1          0            121        43
# 5                   22            -9          1            450        16
# 6                    0             1          1             90        27
# 7                   42           -22          1            780         6
# 8                    0            23          0            312       537
# 9                    2            -1          0            157        16
# 10                   0             0          0             25         1
# 11                   0             0          0             97        17
# ..                 ...           ...        ...            ...       ...
# 34                   0             0          0              9        17
# 35                   4            -1          0            174        15
# 36                  12            -6          0            423        13
# 37                   0             0          0            235        17
# 38                   0             0          0             16        17
# 0                    0             0          0            578      1025
# 1                    0             5          0            548       114
# 2                    0             0          0            213      1025
# 3                    0             0          0             52         1
# 4                    0            -1          0            256         1
# 5                    4             2          0            323        75
# 6                    0             3          0            381        71
# 7                   24           -13          0            542        25
# 8                    2            -1          0            310         0
# 9                    2            -1          0             31        16
# 10                   0             1          0             88        17
# 11                   0             0          0             52        16
# 12                   0             1          0            290        41
# 13                   0             0          0             84        16
# 14                   0             0          0             12        16
# 15                   2            -1          0            180        16
# 16                   0             0          0             53        16
# 17                   0             1          0            150        27
# 18                   4             0          0            201        26
# 19                   0             2          0            304        53
# 20                   2             1          0             73        35
# 21                   0             0          0             59        17
# 22                   4            -2          0            135        14
# 23                   2            -1          0             40        16
# 24                   2            -1          0            229        16
#
#           time
# 0   2019-07-25
# 1   2019-07-25
# 2   2019-07-25
# 3   2019-07-25
# 4   2019-07-25
# 5   2019-07-25
# 6   2019-07-25
# 7   2019-07-25
# 8   2019-07-25
# 9   2019-07-25
# 10  2019-07-25
# 11  2019-07-25
# 12  2019-07-25
# 13  2019-07-25
# 14  2019-07-25
# 15  2019-07-25
# 16  2019-07-25
# 17  2019-07-25
# 0   2019-05-12
# 1   2019-05-12
# 2   2019-05-12
# 3   2019-05-12
# 4   2019-05-12
# 5   2019-05-12
# 6   2019-05-12
# 7   2019-05-12
# 8   2019-05-12
# 9   2019-05-12
# 10  2019-05-12
# 11  2019-05-12
# ..         ...
# 34  2012-12-21
# 35  2012-12-21
# 36  2012-12-21
# 37  2012-12-21
# 38  2012-12-21
# 0   2012-09-19
# 1   2012-09-19
# 2   2012-09-19
# 3   2012-09-19
# 4   2012-09-19
# 5   2012-09-19
# 6   2012-09-19
# 7   2012-09-19
# 8   2012-09-19
# 9   2012-09-19
# 10  2012-09-19
# 11  2012-09-19
# 12  2012-09-19
# 13  2012-09-19
# 14  2012-09-19
# 15  2012-09-19
# 16  2012-09-19
# 17  2012-09-19
# 18  2012-09-19
# 19  2012-09-19
# 20  2012-09-19
# 21  2012-09-19
# 22  2012-09-19
# 23  2012-09-19
# 24  2012-09-19
#
# [2404 rows x 50 columns]

# %% [markdown]
# ### How many times did we sample from?

# %%
print metricsData['times']
# Out:
# 47

# %% [markdown]
# ### How many features and samples are in our dataset?

# %%
print metricsData['data'].shape
# Out:
# (2404, 50)

# %% [markdown]
# ### How many unique source files were measured?

# %%
print metricsData['data']['entity'].nunique()
# Out:
# 843

# %%
print metricsData['data'].head
# Out:
# <bound method DataFrame.head of                                                entity  age-months  n-authors  \
# 0   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 1   okhttp-sse/src/test/java/okhttp3/internal/sse/...           0          2
# 2   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 3         okhttp/src/test/java/okhttp3/CacheTest.java           1          3
# 4   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           1          2
# 5   okhttp/src/test/java/okhttp3/EventListenerTest...           1          3
# 6   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           1          2
# 7          okhttp/src/test/java/okhttp3/CallTest.java           1          4
# 8    okhttp/src/test/java/okhttp3/DispatcherTest.java           1          2
# 9   okhttp/src/test/java/okhttp3/internal/connecti...           1          3
# 10       okhttp/src/test/java/okhttp3/DuplexTest.java           1          2
# 11      okhttp/src/test/java/okhttp3/CookiesTest.java           2          1
# 12  okhttp/src/test/java/okhttp3/InterceptorTest.java           2          1
# 13  okhttp/src/test/java/okhttp3/URLConnectionTest...           2          1
# 14  okhttp/src/test/java/okhttp3/WholeOperationTim...           2          2
# 15  okhttp/src/test/java/okhttp3/internal/tls/Clie...           2          2
# 16  okhttp/src/test/java/okhttp3/ConnectionReuseTe...           2          1
# 17  okhttp-testing-support/src/main/java/okhttp3/T...           3          1
# 0   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           4          2
# 1   okhttp/src/test/java/okhttp3/EventListenerTest...           4          2
# 2   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 3   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           4          2
# 4   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 5   okhttp/src/test/java/okhttp3/internal/http2/Ht...           4          3
# 6   okhttp-logging-interceptor/src/test/java/okhtt...           4          3
# 7   okhttp/src/test/java/okhttp3/URLConnectionTest...           4          3
# 8   okhttp/src/test/java/okhttp3/RecordingEventLis...           4          1
# 9        okhttp/src/test/java/okhttp3/DuplexTest.java           4          2
# 10  okhttp/src/test/java/okhttp3/internal/platform...           5          1
# 11  okhttp/src/test/java/okhttp3/internal/ws/WebSo...           5          2
# ..                                                ...         ...        ...
# 34  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 35  src/main/java/com/squareup/okhttp/internal/net...          83          1
# 36  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 37  src/test/java/com/squareup/okhttp/internal/io/...          83          1
# 38  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 0   src/main/java/com/squareup/okhttp/OkHttpConnec...          84          1
# 1   src/main/java/libcore/net/http/HttpTransport.java          84          1
# 2   src/main/java/com/squareup/okhttp/OkHttpsConne...          84          2
# 3   src/main/java/libcore/util/ExtendedResponseCac...          84          2
# 4   src/main/java/libcore/net/http/HttpURLConnecti...          84          2
# 5   src/main/java/libcore/net/http/HttpResponseCac...          84          3
# 6   src/main/java/libcore/net/http/HttpsURLConnect...          84          2
# 7   src/test/java/libcore/net/http/URLConnectionTe...          84          3
# 8      src/main/java/libcore/net/http/HttpEngine.java          84          2
# 9   src/test/java/libcore/net/http/ExternalSpdyExa...          84          1
# 10   src/main/java/libcore/net/http/HeaderParser.java          85          2
# 11  src/main/java/libcore/net/http/RetryableOutput...          85          1
# 12  src/main/java/libcore/net/http/HttpConnection....          85          1
# 13  src/main/java/libcore/net/http/HttpConnectionP...          85          1
# 14      src/main/java/libcore/net/http/Challenge.java          85          1
# 15     src/main/java/libcore/net/http/RawHeaders.java          85          1
# 16     src/main/java/libcore/net/spdy/SpdyWriter.java          85          2
# 17            src/main/java/libcore/util/Libcore.java          85          1
# 18  src/main/java/libcore/net/spdy/SpdyConnection....          86          1
# 19     src/main/java/libcore/net/spdy/SpdyStream.java          86          1
# 20   src/test/java/libcore/net/spdy/MockSpdyPeer.java          86          1
# 21     src/main/java/libcore/net/spdy/SpdyServer.java          86          1
# 22     src/main/java/libcore/net/spdy/SpdyReader.java          86          1
# 23  src/test/java/libcore/net/spdy/SpdyConnectionT...          86          1
# 24  src/main/java/libcore/net/http/ResponseHeaders...          86          1
#
#     n-revs  added  deleted  fractal-value  soc  netchurn  cbo  ...  \
# 0        6     90       61           0.28    8        29   34  ...
# 1        2      3        8           0.50   12        -5   12  ...
# 2        6    128        6           0.44   14       122   86  ...
# 3        4     43        9           0.63    7        34   37  ...
# 4        2    105        7           0.50    6        98   20  ...
# 5        4      8       18           0.63   28       -10   68  ...
# 6        4     17       17           0.50   24         0   40  ...
# 7       10     95       19           0.64   32        76  118  ...
# 8        2      5        6           0.50   16        -1   16  ...
# 9        6     49       22           0.50    8        27   13  ...
# 10       3      5        5           0.44   23         0   27  ...
# 11       1      1        6           0.00   10        -5   15  ...
# 12       2     13       11           0.00   10         2   41  ...
# 13       1      1        2           0.00   10        -1  120  ...
# 14       2      6        7           0.50   10        -1   23  ...
# 15       2      5        0           0.50    9         5   14  ...
# 16       1      1        6           0.00   10        -5   18  ...
# 17       1     12        0           0.00    7        12    2  ...
# 0        4      3       18           0.38   40       -15   21  ...
# 1        6     44       28           0.44   81        16   68  ...
# 2        1      9        0           0.00    6         9   21  ...
# 3        5     34       25           0.48   47         9   37  ...
# 4        1      9        0           0.00    6         9   13  ...
# 5        8     58       56           0.59   68         2   86  ...
# 6        4     17        7           0.63   37        10   21  ...
# 7        9     37       28           0.64   84         9  120  ...
# 8        1     27        0           0.00    6        27  104  ...
# 9        3      8        8           0.44   42         0   27  ...
# 10       1      1        1           0.00   14         0    4  ...
# 11       3      5        4           0.44   27         1    8  ...
# ..     ...    ...      ...            ...  ...       ...  ...  ...
# 34       2      4       44           0.00   17       -40    1  ...
# 35       3     30        8           0.00   18        22    9  ...
# 36       2    252      270           0.00   15       -18   22  ...
# 37       1     61       87           0.00   12       -26    6  ...
# 38       1      5        4           0.00   12         1    2  ...
# 0        1      0      829           0.00   11      -829    3  ...
# 1        6     70      109           0.00   33       -39   40  ...
# 2        2      0      300           0.50   15      -300    2  ...
# 3        2      5        3           0.50   18         2    2  ...
# 4        8     84      116           0.22   42       -32   13  ...
# 5        6     43       45           0.50   24        -2   41  ...
# 6        4     31      104           0.38   27       -73   28  ...
# 7       14    563      216           0.26   55       347   45  ...
# 8        8     72       50           0.22   48        22   15  ...
# 9        1      3        3           0.00   11         0    2  ...
# 10       2      2       54           0.50   13       -52    4  ...
# 11       1      5        4           0.00    9         1    4  ...
# 12       6    323      326           0.00   32        -3   16  ...
# 13       2      3       10           0.00   13        -7    4  ...
# 14       1      0       40           0.00   11       -40    1  ...
# 15       4     76       33           0.00   28        43    2  ...
# 16       6     96       62           0.28   22        34    2  ...
# 17       3      5      153           0.00   14      -148    8  ...
# 18       9    452      343           0.00   34       109   18  ...
# 19       4    127       76           0.00   12        51   13  ...
# 20       4     79       20           0.00   19        59   10  ...
# 21       2     12        6           0.00    7         6    5  ...
# 22       7    119       74           0.00   29        45    6  ...
# 23       8    536      113           0.00   32       423    9  ...
# 24       1      2        1           0.00    7         1    9  ...
#
#    assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# 0             262                12          261               3
# 1              12                 3           10               0
# 2             231                 7          214               8
# 3             295               136          282               1
# 4              34                 0           32               1
# 5             154                11          141               5
# 6              89                 8           82               2
# 7             435                35          377              10
# 8              36                 0           36               2
# 9              28                 0           28               1
# 10             70                 0           64               2
# 11             63                 9           55               2
# 12            136                12          142               5
# 13            390                45          329               5
# 14             36                 1           36               3
# 15             41                 0           40               1
# 16             53                 0           48               1
# 17              5                 2            4               1
# 0              36                 0           32               1
# 1             155                11          141               5
# 2              11                 2           11               2
# 3              88                 8           81               2
# 4               7                 2            7               2
# 5             229                 7          214               8
# 6              13                22           11               1
# 7             390                45          329               5
# 8              35                 5           32               1
# 9              70                 0           64               2
# 10              1                 0            1               0
# 11             11                 1           11               2
# ..            ...               ...          ...             ...
# 34              0                 0            0               0
# 35             47                13           44               2
# 36            172                92          165               6
# 37             88                 8           67               2
# 38              5                 0            5               0
# 0              60                 6           50               2
# 1              72                 9           47              10
# 2              10                 0            6               1
# 3               0                 0            0              -1
# 4              39                 6           30               2
# 5              80                12           67              10
# 6              22                 1           16               3
# 7             196                21          191               1
# 8              65                 4           50               3
# 9               5                 1            5               1
# 10             27                 0           16               2
# 11              5                 3            2               1
# 12             47                14           33               4
# 13             17                 3           13               3
# 14              2                 2            2               0
# 15             65                29           43               4
# 16             14                12           20               1
# 17             28                10           19               3
# 18             48                 2           35               5
# 19             58                16           32               7
# 20             24                 0           21               4
# 21             17                 3           15               2
# 22             40                 7           33               4
# 23             21                 0           13               0
# 24             57                10           45               4
#
#    anonymousClassesQty subClassesQty lambdasQty uniqueWordsQty modifiers  \
# 0                    6            -2          0            391        24
# 1                    0             0          0             45        17
# 2                   22            -9          1            438        16
# 3                    6            -4          3            561        14
# 4                    2            -1          3            182        16
# 5                   12            -5          3            239        13
# 6                   14            -7          3            248        10
# 7                   52           -25          8            731         1
# 8                    0             0          4            120        17
# 9                    0             0          0             91        17
# 10                   2            -1          0            157        16
# 11                   4            -2          0            111        -1
# 12                   6            -2         31            208        24
# 13                  42           -22          1            781         6
# 14                   8            -4          0             97        13
# 15                   0             0          0             89        17
# 16                   0             0          1            145        17
# 17                   0             0          0             50        17
# 0                    2            -1          3            191        16
# 1                   12            -5          3            239        13
# 2                    6            -2          0            137        40
# 3                   14            -7          3            249        10
# 4                    0             1          0            121        43
# 5                   22            -9          1            450        16
# 6                    0             1          1             90        27
# 7                   42           -22          1            780         6
# 8                    0            23          0            312       537
# 9                    2            -1          0            157        16
# 10                   0             0          0             25         1
# 11                   0             0          0             97        17
# ..                 ...           ...        ...            ...       ...
# 34                   0             0          0              9        17
# 35                   4            -1          0            174        15
# 36                  12            -6          0            423        13
# 37                   0             0          0            235        17
# 38                   0             0          0             16        17
# 0                    0             0          0            578      1025
# 1                    0             5          0            548       114
# 2                    0             0          0            213      1025
# 3                    0             0          0             52         1
# 4                    0            -1          0            256         1
# 5                    4             2          0            323        75
# 6                    0             3          0            381        71
# 7                   24           -13          0            542        25
# 8                    2            -1          0            310         0
# 9                    2            -1          0             31        16
# 10                   0             1          0             88        17
# 11                   0             0          0             52        16
# 12                   0             1          0            290        41
# 13                   0             0          0             84        16
# 14                   0             0          0             12        16
# 15                   2            -1          0            180        16
# 16                   0             0          0             53        16
# 17                   0             1          0            150        27
# 18                   4             0          0            201        26
# 19                   0             2          0            304        53
# 20                   2             1          0             73        35
# 21                   0             0          0             59        17
# 22                   4            -2          0            135        14
# 23                   2            -1          0             40        16
# 24                   2            -1          0            229        16
#
#           time
# 0   2019-07-25
# 1   2019-07-25
# 2   2019-07-25
# 3   2019-07-25
# 4   2019-07-25
# 5   2019-07-25
# 6   2019-07-25
# 7   2019-07-25
# 8   2019-07-25
# 9   2019-07-25
# 10  2019-07-25
# 11  2019-07-25
# 12  2019-07-25
# 13  2019-07-25
# 14  2019-07-25
# 15  2019-07-25
# 16  2019-07-25
# 17  2019-07-25
# 0   2019-05-12
# 1   2019-05-12
# 2   2019-05-12
# 3   2019-05-12
# 4   2019-05-12
# 5   2019-05-12
# 6   2019-05-12
# 7   2019-05-12
# 8   2019-05-12
# 9   2019-05-12
# 10  2019-05-12
# 11  2019-05-12
# ..         ...
# 34  2012-12-21
# 35  2012-12-21
# 36  2012-12-21
# 37  2012-12-21
# 38  2012-12-21
# 0   2012-09-19
# 1   2012-09-19
# 2   2012-09-19
# 3   2012-09-19
# 4   2012-09-19
# 5   2012-09-19
# 6   2012-09-19
# 7   2012-09-19
# 8   2012-09-19
# 9   2012-09-19
# 10  2012-09-19
# 11  2012-09-19
# 12  2012-09-19
# 13  2012-09-19
# 14  2012-09-19
# 15  2012-09-19
# 16  2012-09-19
# 17  2012-09-19
# 18  2012-09-19
# 19  2012-09-19
# 20  2012-09-19
# 21  2012-09-19
# 22  2012-09-19
# 23  2012-09-19
# 24  2012-09-19
#
# [2404 rows x 50 columns]>

# %% [markdown]
# ### Let's see what affects the net churn of files
# ### Which types of files have net churn above and below the mean net churn?

# %%
# We instantiate the scikit-learn decision tree classification model
# It is trained with a maximum number of leaf nodes
# Samples are binned so as to maximize information gain at higher nodes ('entropy')
from sklearn.tree import DecisionTreeClassifier
modelInstance = DecisionTreeClassifier(max_leaf_nodes=8, criterion='entropy')
modelSimpler = DecisionTreeClassifier(max_leaf_nodes=4, criterion='entropy')
churnModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsData['data'], 2, 'netchurn', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 0.263114
# accuracy_score: 0.263114
#              precision    recall  f1-score   support
#
#        -829       0.00      0.00      0.00         1
#        -745       0.00      0.00      0.00         1
#        -682       0.00      0.00      0.00         1
#        -515       0.00      0.00      0.00         1
#        -505       0.00      0.00      0.00         1
#        -452       0.00      0.00      0.00         1
#        -428       0.00      0.00      0.00         1
#        -367       0.00      0.00      0.00         1
#        -360       0.00      0.00      0.00         1
#        -317       0.00      0.00      0.00         2
#        -300       0.00      0.00      0.00         1
#        -294       0.00      0.00      0.00         1
#        -270       0.00      0.00      0.00         1
#        -255       0.00      0.00      0.00         1
#        -234       0.00      0.00      0.00         1
#        -215       0.00      0.00      0.00         1
#        -211       0.00      0.00      0.00         1
#        -208       0.00      0.00      0.00         1
#        -205       0.00      0.00      0.00         1
#        -200       0.00      0.00      0.00         1
#        -192       0.00      0.00      0.00         1
#        -191       0.00      0.00      0.00         1
#        -190       0.00      0.00      0.00         1
#        -182       0.00      0.00      0.00         1
#        -177       0.00      0.00      0.00         1
#        -167       0.00      0.00      0.00         1
#        -165       0.00      0.00      0.00         1
#        -158       0.00      0.00      0.00         1
#        -148       0.00      0.00      0.00         2
#        -147       0.00      0.00      0.00         1
#        -146       0.00      0.00      0.00         1
#        -142       0.00      0.00      0.00         1
#        -141       0.00      0.00      0.00         1
#        -140       0.00      0.00      0.00         1
#        -138       0.00      0.00      0.00         1
#        -137       0.00      0.00      0.00         1
#        -135       0.00      0.00      0.00         2
#        -127       0.00      0.00      0.00         1
#        -125       0.00      0.00      0.00         1
#        -124       0.00      0.00      0.00         1
#        -123       0.00      0.00      0.00         1
#        -117       0.00      0.00      0.00         1
#        -115       0.00      0.00      0.00         1
#        -114       0.00      0.00      0.00         1
#        -107       0.00      0.00      0.00         2
#        -101       0.00      0.00      0.00         1
#         -95       0.00      0.00      0.00         1
#         -89       0.00      0.00      0.00         1
#         -88       0.00      0.00      0.00         1
#         -87       0.00      0.00      0.00         2
#         -84       0.00      0.00      0.00         2
#         -81       0.00      0.00      0.00         3
#         -75       0.00      0.00      0.00         1
#         -73       0.00      0.00      0.00         1
#         -72       0.00      0.00      0.00         3
#         -71       0.00      0.00      0.00         2
#         -70       0.00      0.00      0.00         4
#         -69       0.00      0.00      0.00         1
#         -68       0.00      0.00      0.00         2
#         -67       0.00      0.00      0.00         1
#         -66       0.00      0.00      0.00         1
#         -63       0.00      0.00      0.00         2
#         -61       0.00      0.00      0.00         4
#         -59       0.00      0.00      0.00         3
#         -58       0.00      0.00      0.00         1
#         -57       0.00      0.00      0.00         1
#         -56       0.00      0.00      0.00         3
#         -55       0.00      0.00      0.00         3
#         -54       0.00      0.00      0.00         1
#         -53       0.00      0.00      0.00         1
#         -52       0.00      0.00      0.00         2
#         -51       0.00      0.00      0.00         1
#         -49       0.00      0.00      0.00         1
#         -48       0.00      0.00      0.00         2
#         -45       0.00      0.00      0.00         2
#         -44       0.00      0.00      0.00         1
#         -42       0.00      0.00      0.00         2
#         -41       0.00      0.00      0.00         1
#         -40       0.00      0.00      0.00         2
#         -39       0.00      0.00      0.00         1
#         -38       0.00      0.00      0.00         1
#         -37       0.00      0.00      0.00         2
#         -36       0.00      0.00      0.00         1
#         -34       0.00      0.00      0.00         1
#         -33       0.00      0.00      0.00         2
#         -32       0.00      0.00      0.00         2
#         -30       0.00      0.00      0.00         3
#         -29       0.00      0.00      0.00         2
#         -28       0.00      0.00      0.00         3
#         -27       0.00      0.00      0.00         1
#         -26       0.00      0.00      0.00         3
#         -25       0.00      0.00      0.00         1
#         -24       0.00      0.00      0.00         3
#         -22       0.00      0.00      0.00         5
#         -21       0.00      0.00      0.00         3
#         -20       0.00      0.00      0.00         2
#         -18       0.00      0.00      0.00         5
#         -17       0.00      0.00      0.00         3
#         -16       0.00      0.00      0.00         1
#         -15       0.00      0.00      0.00         7
#         -14       0.00      0.00      0.00         4
#         -13       0.00      0.00      0.00         3
#         -12       0.00      0.00      0.00         7
#         -11       0.00      0.00      0.00         7
#         -10       0.00      0.00      0.00         1
#          -9       0.00      0.00      0.00         6
#          -8       0.00      0.00      0.00         8
#          -7       0.00      0.00      0.00        16
#          -6       0.00      0.00      0.00        10
#          -5       0.00      0.00      0.00        11
#          -4       0.00      0.00      0.00        16
#          -3       0.00      0.00      0.00        17
#          -2       0.00      0.00      0.00        32
#          -1       0.15      0.12      0.14        72
#           0       0.43      0.93      0.58       320
#           1       0.00      0.00      0.00        65
#           2       0.01      0.02      0.01        43
#           3       0.00      0.00      0.00        20
#           4       0.00      0.00      0.00        28
#           5       0.00      0.00      0.00        19
#           6       0.00      0.00      0.00        13
#           7       0.00      0.00      0.00        19
#           8       0.00      0.00      0.00        15
#           9       0.00      0.00      0.00        10
#          10       0.00      0.00      0.00         8
#          11       0.00      0.00      0.00        12
#          12       0.00      0.00      0.00        10
#          13       0.00      0.00      0.00         6
#          14       0.00      0.00      0.00         7
#          15       0.06      0.86      0.11         7
#          16       0.00      0.00      0.00        11
#          17       0.00      0.00      0.00         4
#          18       0.00      0.00      0.00        10
#          19       0.00      0.00      0.00         7
#          20       0.00      0.00      0.00         6
#          21       0.00      0.00      0.00        10
#          22       0.00      0.00      0.00         6
#          23       0.00      0.00      0.00         3
#          24       0.00      0.00      0.00         5
#          25       0.00      0.00      0.00         5
#          26       0.00      0.00      0.00         3
#          27       0.00      0.00      0.00         6
#          28       0.00      0.00      0.00         5
#          29       0.00      0.00      0.00         5
#          30       0.00      0.00      0.00         9
#          31       0.00      0.00      0.00         6
#          32       0.00      0.00      0.00         3
#          33       0.00      0.00      0.00         4
#          34       0.00      0.00      0.00         3
#          35       0.00      0.00      0.00         1
#          37       0.00      0.00      0.00         4
#          38       0.00      0.00      0.00         4
#          40       0.00      0.00      0.00         2
#          41       0.00      0.00      0.00         1
#          42       0.00      0.00      0.00         2
#          43       0.00      0.00      0.00         3
#          44       0.00      0.00      0.00         1
#          45       0.00      0.00      0.00         4
#          46       0.00      0.00      0.00         3
#          47       0.00      0.00      0.00         2
#          48       0.00      0.00      0.00         1
#          50       0.00      0.00      0.00         2
#          51       0.00      0.00      0.00         4
#          52       0.01      1.00      0.03         1
#          53       0.00      0.00      0.00         3
#          54       0.00      0.00      0.00         3
#          55       0.00      0.00      0.00         1
#          56       0.00      0.00      0.00         1
#          58       0.00      0.00      0.00         2
#          59       0.00      0.00      0.00         3
#          61       0.00      0.00      0.00         2
#          62       0.00      0.00      0.00         2
#          63       0.00      0.00      0.00         2
#          65       0.00      0.00      0.00         1
#          66       0.00      0.00      0.00         1
#          70       0.00      0.00      0.00         1
#          71       0.00      0.00      0.00         2
#          73       0.00      0.00      0.00         2
#          74       0.00      0.00      0.00         1
#          75       0.00      0.00      0.00         3
#          76       0.00      0.00      0.00         1
#          78       0.00      0.00      0.00         1
#          79       0.00      0.00      0.00         1
#          80       0.00      0.00      0.00         1
#          81       0.00      0.00      0.00         2
#          87       0.00      0.00      0.00         1
#          88       0.00      0.00      0.00         1
#          92       0.00      0.00      0.00         2
#          93       0.00      0.00      0.00         1
#          94       0.00      0.00      0.00         3
#          96       0.00      0.00      0.00         2
#         100       0.00      0.00      0.00         1
#         101       0.00      0.00      0.00         2
#         102       0.00      0.00      0.00         3
#         105       0.00      0.00      0.00         1
#         109       0.00      0.00      0.00         1
#         113       0.00      0.00      0.00         1
#         114       0.00      0.00      0.00         1
#         117       0.00      0.00      0.00         1
#         122       0.00      0.00      0.00         1
#         130       0.00      0.00      0.00         1
#         132       0.00      0.00      0.00         1
#         150       0.00      0.00      0.00         1
#         151       0.00      0.00      0.00         1
#         153       0.00      0.00      0.00         1
#         154       0.00      0.00      0.00         1
#         155       0.00      0.00      0.00         3
#         158       0.00      0.00      0.00         1
#         161       0.00      0.00      0.00         1
#         182       0.00      0.00      0.00         1
#         249       0.00      0.00      0.00         1
#         265       0.00      0.00      0.00         1
#         290       0.00      0.00      0.00         1
#         347       0.00      0.00      0.00         1
#         355       0.00      0.00      0.00         1
#         370       0.00      0.00      0.00         1
#         374       0.00      0.00      0.00         1
#         385       0.00      0.00      0.00         1
#         401       0.00      0.00      0.00         1
#         423       0.00      0.00      0.00         1
#         448       0.00      0.00      0.00         1
#         614       0.00      0.00      0.00         1
#
# avg / total       0.12      0.26      0.16      1201
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 3    added    0.528543
# 4  deleted    0.471457
# Model.score: 0.253122
# accuracy_score: 0.253122
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/utils/__init__.py:93: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):
#              precision    recall  f1-score   support
#
#        -829       0.00      0.00      0.00         1
#        -745       0.00      0.00      0.00         1
#        -682       0.00      0.00      0.00         1
#        -515       0.00      0.00      0.00         1
#        -505       0.00      0.00      0.00         1
#        -452       0.00      0.00      0.00         1
#        -428       0.00      0.00      0.00         1
#        -367       0.00      0.00      0.00         1
#        -360       0.00      0.00      0.00         1
#        -317       0.00      0.00      0.00         2
#        -300       0.00      0.00      0.00         1
#        -294       0.00      0.00      0.00         1
#        -270       0.00      0.00      0.00         1
#        -255       0.00      0.00      0.00         1
#        -234       0.00      0.00      0.00         1
#        -215       0.00      0.00      0.00         1
#        -211       0.00      0.00      0.00         1
#        -208       0.00      0.00      0.00         1
#        -205       0.00      0.00      0.00         1
#        -200       0.00      0.00      0.00         1
#        -192       0.00      0.00      0.00         1
#        -191       0.00      0.00      0.00         1
#        -190       0.00      0.00      0.00         1
#        -182       0.00      0.00      0.00         1
#        -177       0.00      0.00      0.00         1
#        -167       0.00      0.00      0.00         1
#        -165       0.00      0.00      0.00         1
#        -158       0.00      0.00      0.00         1
#        -148       0.00      0.00      0.00         2
#        -147       0.00      0.00      0.00         1
#        -146       0.00      0.00      0.00         1
#        -142       0.00      0.00      0.00         1
#        -141       0.00      0.00      0.00         1
#        -140       0.00      0.00      0.00         1
#        -138       0.00      0.00      0.00         1
#        -137       0.00      0.00      0.00         1
#        -135       0.00      0.00      0.00         2
#        -127       0.00      0.00      0.00         1
#        -125       0.00      0.00      0.00         1
#        -124       0.00      0.00      0.00         1
#        -123       0.00      0.00      0.00         1
#        -117       0.00      0.00      0.00         1
#        -115       0.00      0.00      0.00         1
#        -114       0.00      0.00      0.00         1
#        -107       0.00      0.00      0.00         2
#        -101       0.00      0.00      0.00         1
#         -95       0.00      0.00      0.00         1
#         -89       0.00      0.00      0.00         1
#         -88       0.00      0.00      0.00         1
#         -87       0.00      0.00      0.00         2
#         -84       0.00      0.00      0.00         2
#         -81       0.00      0.00      0.00         3
#         -75       0.00      0.00      0.00         1
#         -73       0.00      0.00      0.00         1
#         -72       0.00      0.00      0.00         3
#         -71       0.00      0.00      0.00         2
#         -70       0.00      0.00      0.00         4
#         -69       0.00      0.00      0.00         1
#         -68       0.00      0.00      0.00         2
#         -67       0.00      0.00      0.00         1
#         -66       0.00      0.00      0.00         1
#         -63       0.00      0.00      0.00         2
#         -61       0.00      0.00      0.00         4
#         -59       0.00      0.00      0.00         3
#         -58       0.00      0.00      0.00         1
#         -57       0.00      0.00      0.00         1
#         -56       0.00      0.00      0.00         3
#         -55       0.00      0.00      0.00         3
#         -54       0.00      0.00      0.00         1
#         -53       0.00      0.00      0.00         1
#         -52       0.00      0.00      0.00         2
#         -51       0.00      0.00      0.00         1
#         -49       0.00      0.00      0.00         1
#         -48       0.00      0.00      0.00         2
#         -45       0.00      0.00      0.00         2
#         -44       0.00      0.00      0.00         1
#         -42       0.00      0.00      0.00         2
#         -41       0.00      0.00      0.00         1
#         -40       0.00      0.00      0.00         2
#         -39       0.00      0.00      0.00         1
#         -38       0.00      0.00      0.00         1
#         -37       0.00      0.00      0.00         2
#         -36       0.00      0.00      0.00         1
#         -34       0.00      0.00      0.00         1
#         -33       0.00      0.00      0.00         2
#         -32       0.00      0.00      0.00         2
#         -30       0.00      0.00      0.00         3
#         -29       0.00      0.00      0.00         2
#         -28       0.00      0.00      0.00         3
#         -27       0.00      0.00      0.00         1
#         -26       0.00      0.00      0.00         3
#         -25       0.00      0.00      0.00         1
#         -24       0.00      0.00      0.00         3
#         -22       0.00      0.00      0.00         5
#         -21       0.00      0.00      0.00         3
#         -20       0.00      0.00      0.00         2
#         -18       0.00      0.00      0.00         5
#         -17       0.00      0.00      0.00         3
#         -16       0.00      0.00      0.00         1
#         -15       0.00      0.00      0.00         7
#         -14       0.00      0.00      0.00         4
#         -13       0.00      0.00      0.00         3
#         -12       0.00      0.00      0.00         7
#         -11       0.00      0.00      0.00         7
#         -10       0.00      0.00      0.00         1
#          -9       0.00      0.00      0.00         6
#          -8       0.00      0.00      0.00         8
#          -7       0.00      0.00      0.00        16
#          -6       0.00      0.00      0.00        10
#          -5       0.00      0.00      0.00        11
#          -4       0.00      0.00      0.00        16
#          -3       0.00      0.00      0.00        17
#          -2       0.00      0.00      0.00        32
#          -1       0.00      0.00      0.00        72
#           0       0.50      0.93      0.65       320
#           1       0.00      0.00      0.00        65
#           2       0.00      0.02      0.01        43
#           3       0.00      0.00      0.00        20
#           4       0.00      0.00      0.00        28
#           5       0.00      0.00      0.00        19
#           6       0.00      0.00      0.00        13
#           7       0.00      0.00      0.00        19
#           8       0.00      0.00      0.00        15
#           9       0.00      0.00      0.00        10
#          10       0.00      0.00      0.00         8
#          11       0.00      0.00      0.00        12
#          12       0.00      0.00      0.00        10
#          13       0.00      0.00      0.00         6
#          14       0.00      0.00      0.00         7
#          15       0.03      1.00      0.05         7
#          16       0.00      0.00      0.00        11
#          17       0.00      0.00      0.00         4
#          18       0.00      0.00      0.00        10
#          19       0.00      0.00      0.00         7
#          20       0.00      0.00      0.00         6
#          21       0.00      0.00      0.00        10
#          22       0.00      0.00      0.00         6
#          23       0.00      0.00      0.00         3
#          24       0.00      0.00      0.00         5
#          25       0.00      0.00      0.00         5
#          26       0.00      0.00      0.00         3
#          27       0.00      0.00      0.00         6
#          28       0.00      0.00      0.00         5
#          29       0.00      0.00      0.00         5
#          30       0.00      0.00      0.00         9
#          31       0.00      0.00      0.00         6
#          32       0.00      0.00      0.00         3
#          33       0.00      0.00      0.00         4
#          34       0.00      0.00      0.00         3
#          35       0.00      0.00      0.00         1
#          37       0.00      0.00      0.00         4
#          38       0.00      0.00      0.00         4
#          40       0.00      0.00      0.00         2
#          41       0.00      0.00      0.00         1
#          42       0.00      0.00      0.00         2
#          43       0.00      0.00      0.00         3
#          44       0.00      0.00      0.00         1
#          45       0.00      0.00      0.00         4
#          46       0.00      0.00      0.00         3
#          47       0.00      0.00      0.00         2
#          48       0.00      0.00      0.00         1
#          50       0.00      0.00      0.00         2
#          51       0.00      0.00      0.00         4
#          52       0.00      0.00      0.00         1
#          53       0.00      0.00      0.00         3
#          54       0.00      0.00      0.00         3
#          55       0.00      0.00      0.00         1
#          56       0.00      0.00      0.00         1
#          58       0.00      0.00      0.00         2
#          59       0.00      0.00      0.00         3
#          61       0.00      0.00      0.00         2
#          62       0.00      0.00      0.00         2
#          63       0.00      0.00      0.00         2
#          65       0.00      0.00      0.00         1
#          66       0.00      0.00      0.00         1
#          70       0.00      0.00      0.00         1
#          71       0.00      0.00      0.00         2
#          73       0.00      0.00      0.00         2
#          74       0.00      0.00      0.00         1
#          75       0.00      0.00      0.00         3
#          76       0.00      0.00      0.00         1
#          78       0.00      0.00      0.00         1
#          79       0.00      0.00      0.00         1
#          80       0.00      0.00      0.00         1
#          81       0.00      0.00      0.00         2
#          87       0.00      0.00      0.00         1
#          88       0.00      0.00      0.00         1
#          92       0.00      0.00      0.00         2
#          93       0.00      0.00      0.00         1
#          94       0.00      0.00      0.00         3
#          96       0.00      0.00      0.00         2
#         100       0.00      0.00      0.00         1
#         101       0.00      0.00      0.00         2
#         102       0.00      0.00      0.00         3
#         105       0.00      0.00      0.00         1
#         109       0.00      0.00      0.00         1
#         113       0.00      0.00      0.00         1
#         114       0.00      0.00      0.00         1
#         117       0.00      0.00      0.00         1
#         122       0.00      0.00      0.00         1
#         130       0.00      0.00      0.00         1
#         132       0.00      0.00      0.00         1
#         150       0.00      0.00      0.00         1
#         151       0.00      0.00      0.00         1
#         153       0.00      0.00      0.00         1
#         154       0.00      0.00      0.00         1
#         155       0.00      0.00      0.00         3
#         158       0.00      0.00      0.00         1
#         161       0.00      0.00      0.00         1
#         182       0.00      0.00      0.00         1
#         249       0.00      0.00      0.00         1
#         265       0.00      0.00      0.00         1
#         290       0.00      0.00      0.00         1
#         347       0.00      0.00      0.00         1
#         355       0.00      0.00      0.00         1
#         370       0.00      0.00      0.00         1
#         374       0.00      0.00      0.00         1
#         385       0.00      0.00      0.00         1
#         401       0.00      0.00      0.00         1
#         423       0.00      0.00      0.00         1
#         448       0.00      0.00      0.00         1
#         614       0.00      0.00      0.00         1
#
# avg / total       0.13      0.25      0.17      1201
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 0    added    0.656998
# 1  deleted    0.343002

# %% [markdown]
# ### Some observations:
# - The model has very good Precision, Recall and F1-Score: net churn above/below the mean is classified very well by this model
# - ROC area under curve is very high: very little compromise between false negative rate and false positive rate
# - The model says that the features influencing net churn are (strongest to weakest):
#     - Number of lines added
#     - Number of lines deleted
# - The 'net churn below the mean' class is over-represented in our data (3 times as many samples as the other class)
#     - However, the model still performs well without any steps taken to address class imbalance (e.g. under/over-sampling)
# - Interpretation of the visualized decision tree is straightforward:
#     - 63% of samples were files with less than 34 lines added
#         - These samples had net churn less than the mean
#         - Some of these may be very stable files (over the history of the project)
#     - The files with net churn greater than the mean had more than 108 lines added
#     - Within this group, there are several subgroups with varying levels of churn

# %% [markdown]
# ### In the above step, we only performed 2-fold cross validation (1 training set, 1 test set)
#
# ### How does this approach perform with more cross-validation folds in time?

# %%
# We split the data into 5 equally-sized groups, 
# then perform cross-validation while gradually adding these groups to the training set

# i.e. the train-test splits are with groups of size:
# 1-4, 2-3, 3-2, 4-1

# We omit visualization of decision trees to save space,
# but they can be shown with visualize=True as above
folds = 5
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsData['data'], folds, 'netchurn', modelInstance, modelSimpler, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 0.876827
# accuracy_score: 0.876827
#              precision    recall  f1-score   support
#
#           0       0.48      0.70      0.57        56
#           1       0.96      0.90      0.93       423
#
# avg / total       0.90      0.88      0.89       479
#
# roc_auc_score: 0.798569
#              name  importance
# 4         deleted    0.456808
# 3           added    0.428954
# 37     numbersQty    0.046011
# 47           time    0.043791
# 26  defaultFields    0.024436
# Model.score: 0.929019
# accuracy_score: 0.929019
#              precision    recall  f1-score   support
#
#           0       0.96      0.40      0.56        55
#           1       0.93      1.00      0.96       424
#
# avg / total       0.93      0.93      0.92       479
#
# roc_auc_score: 0.698821
#       name  importance
# 4  deleted     0.54168
# 3    added     0.45832
# Model.score: 0.933194
# accuracy_score: 0.933194
#              precision    recall  f1-score   support
#
#           0       0.98      0.59      0.74        76
#           1       0.93      1.00      0.96       403
#
# avg / total       0.94      0.93      0.93       479
#
# roc_auc_score: 0.794812
#       name  importance
# 4  deleted    0.584007
# 3    added    0.415993
# Model.score: 0.903967
# accuracy_score: 0.903967
#              precision    recall  f1-score   support
#
#           0       0.91      0.66      0.77       114
#           1       0.90      0.98      0.94       365
#
# avg / total       0.90      0.90      0.90       479
#
# roc_auc_score: 0.819358
#       name  importance
# 4  deleted    0.549266
# 3    added    0.450734
# Model.score: 0.958246
# accuracy_score: 0.958246
#              precision    recall  f1-score   support
#
#           0       1.00      0.64      0.78        56
#           1       0.95      1.00      0.98       423
#
# avg / total       0.96      0.96      0.95       479
#
# roc_auc_score: 0.821429
#       name  importance
# 1  deleted    0.557762
# 0    added    0.442238
# Model.score: 0.910230
# accuracy_score: 0.910230
#              precision    recall  f1-score   support
#
#           0       1.00      0.22      0.36        55
#           1       0.91      1.00      0.95       424
#
# avg / total       0.92      0.91      0.88       479
#
# roc_auc_score: 0.609091
#       name  importance
# 1  deleted    0.540771
# 0    added    0.459229
# Model.score: 0.895616
# accuracy_score: 0.895616
#              precision    recall  f1-score   support
#
#           0       1.00      0.34      0.51        76
#           1       0.89      1.00      0.94       403
#
# avg / total       0.91      0.90      0.87       479
#
# roc_auc_score: 0.671053
#       name  importance
# 1  deleted    0.606279
# 0    added    0.393721
# Model.score: 0.874739
# accuracy_score: 0.874739
#              precision    recall  f1-score   support
#
#           0       1.00      0.47      0.64       114
#           1       0.86      1.00      0.92       365
#
# avg / total       0.89      0.87      0.86       479
#
# roc_auc_score: 0.736842
#       name  importance
# 1  deleted    0.657703
# 0    added    0.342297

# %% [markdown]
# ### Each of the subsets still exhibits class imbalance (but not with the same ratio)
# ### In particular, the 2nd train-test split has the most balanced classes (2:1) among the five splits
#
# ### We still see very good performance, and the same features are important throughout
# ### How far can we go? Let's cross-validate on every sampled time!

# %%
folds = metricsData['times'] # This is an attribute of the measured data set: the number of time points measured
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsData['data'], folds, 'netchurn', modelInstance, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 1.000000
# accuracy_score: 1.000000
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        14
#           1       1.00      1.00      1.00        36
#
# avg / total       1.00      1.00      1.00        50
#
# roc_auc_score: 1.000000
#       name  importance
# 3    added    0.591433
# 4  deleted    0.408567
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.82      0.90        17
#           1       0.92      1.00      0.96        33
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.911765
#       name  importance
# 4  deleted    0.553347
# 3    added    0.446653
# Model.score: 0.900000
# accuracy_score: 0.900000
#              precision    recall  f1-score   support
#
#           0       0.75      0.92      0.83        13
#           1       0.97      0.89      0.93        37
#
# avg / total       0.91      0.90      0.90        50
#
# roc_auc_score: 0.907484
#                                                   name  importance
# 4                                              deleted    0.548491
# 3                                                added    0.304449
# 13                                       staticMethods    0.077475
# 149  entity_okhttp-logging-interceptor/src/test/jav...    0.052480
# 12                                        totalMethods    0.017105
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.78      0.88         9
#           1       0.95      1.00      0.98        41
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.888889
#             name  importance
# 4        deleted    0.459887
# 3          added    0.448683
# 2         n-revs    0.068950
# 40  variablesQty    0.022480
# Model.score: 0.820000
# accuracy_score: 0.820000
#              precision    recall  f1-score   support
#
#           0       0.92      0.58      0.71        19
#           1       0.79      0.97      0.87        31
#
# avg / total       0.84      0.82      0.81        50
#
# roc_auc_score: 0.773345
#                                                   name  importance
# 3                                                added    0.475482
# 4                                              deleted    0.386543
# 2                                               n-revs    0.059808
# 288  entity_okhttp-tests/src/test/java/okhttp3/Conn...    0.034878
# 19                                        finalMethods    0.024822
# 27                                         finalFields    0.018466
# Model.score: 0.740000
# accuracy_score: 0.740000
#              precision    recall  f1-score   support
#
#           0       0.52      1.00      0.68        14
#           1       1.00      0.64      0.78        36
#
# avg / total       0.87      0.74      0.75        50
#
# roc_auc_score: 0.819444
#              name  importance
# 3           added    0.564086
# 4         deleted    0.351803
# 47           time    0.032013
# 26  defaultFields    0.028936
# 32        loopQty    0.023162
# Model.score: 0.820000
# accuracy_score: 0.820000
#              precision    recall  f1-score   support
#
#           0       1.00      0.25      0.40        12
#           1       0.81      1.00      0.89        38
#
# avg / total       0.85      0.82      0.78        50
#
# roc_auc_score: 0.625000
#                     name  importance
# 4                deleted    0.458515
# 3                  added    0.369206
# 36     stringLiteralsQty    0.058027
# 37            numbersQty    0.040878
# 35  parenthesizedExpsQty    0.037279
# 46             modifiers    0.036095
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       0.60      1.00      0.75         3
#           1       1.00      0.96      0.98        47
#
# avg / total       0.98      0.96      0.96        50
#
# roc_auc_score: 0.978723
#                name  importance
# 3             added    0.402094
# 4           deleted    0.399024
# 47             time    0.055281
# 41  maxNestedBlocks    0.043992
# 37       numbersQty    0.040785
# 18  abstractMethods    0.030498
# 26    defaultFields    0.028326
# Model.score: 0.900000
# accuracy_score: 0.900000
#              precision    recall  f1-score   support
#
#           0       0.71      0.91      0.80        11
#           1       0.97      0.90      0.93        39
#
# avg / total       0.92      0.90      0.90        50
#
# roc_auc_score: 0.903263
#           name  importance
# 4      deleted    0.472724
# 3        added    0.436447
# 47        time    0.046185
# 37  numbersQty    0.044643
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         6
#           1       0.92      1.00      0.96        44
#
# avg / total       0.93      0.92      0.90        50
#
# roc_auc_score: 0.666667
#           name  importance
# 4      deleted    0.489085
# 3        added    0.478767
# 37  numbersQty    0.032148
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         2
#           1       0.98      1.00      0.99        48
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.750000
#           name  importance
# 3        added    0.502587
# 4      deleted    0.471385
# 37  numbersQty    0.026028
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#           name  importance
# 3        added    0.511474
# 4      deleted    0.459082
# 37  numbersQty    0.029445
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.33      0.50      0.40         2
#           1       0.98      0.96      0.97        48
#
# avg / total       0.95      0.94      0.95        50
#
# roc_auc_score: 0.729167
#           name  importance
# 3        added    0.513011
# 4      deleted    0.461463
# 37  numbersQty    0.025526
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67         1
#           1       1.00      0.98      0.99        49
#
# avg / total       0.99      0.98      0.98        50
#
# roc_auc_score: 0.989796
#             name  importance
# 3          added    0.515517
# 4        deleted    0.452762
# 22  staticFields    0.031722
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.98      1.00      0.99        49
#
# avg / total       0.96      0.98      0.97        50
#
# roc_auc_score: 0.500000
#       name  importance
# 3    added    0.525323
# 4  deleted    0.474677
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         2
#           1       0.98      1.00      0.99        48
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.750000
#       name  importance
# 3    added    0.613753
# 4  deleted    0.386247
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.79      0.88        14
#           1       0.92      1.00      0.96        36
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.892857
#       name  importance
# 3    added    0.549444
# 4  deleted    0.450556
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.85      0.92        13
#           1       0.95      1.00      0.97        37
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.923077
#       name  importance
# 4  deleted    0.525426
# 3    added    0.474574
# Model.score: 0.840000
# accuracy_score: 0.840000
#              precision    recall  f1-score   support
#
#           0       0.75      0.30      0.43        10
#           1       0.85      0.97      0.91        40
#
# avg / total       0.83      0.84      0.81        50
#
# roc_auc_score: 0.637500
#       name  importance
# 4  deleted    0.540762
# 3    added    0.459238
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.67      1.00      0.80         2
#           1       1.00      0.98      0.99        48
#
# avg / total       0.99      0.98      0.98        50
#
# roc_auc_score: 0.989583
#       name  importance
# 3    added    0.511304
# 4  deleted    0.488696
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#       name  importance
# 3    added    0.508575
# 4  deleted    0.491425
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.67      0.80         3
#           1       0.98      1.00      0.99        47
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.833333
#       name  importance
# 3    added    0.507895
# 4  deleted    0.492105
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         3
#           1       0.96      1.00      0.98        47
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.666667
#       name  importance
# 3    added    0.503881
# 4  deleted    0.496119
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         6
#           1       0.92      1.00      0.96        44
#
# avg / total       0.93      0.92      0.90        50
#
# roc_auc_score: 0.666667
#       name  importance
# 3    added    0.500056
# 4  deleted    0.499944
# Model.score: 0.900000
# accuracy_score: 0.900000
#              precision    recall  f1-score   support
#
#           0       1.00      0.17      0.29         6
#           1       0.90      1.00      0.95        44
#
# avg / total       0.91      0.90      0.87        50
#
# roc_auc_score: 0.583333
#       name  importance
# 4  deleted    0.507929
# 3    added    0.492071
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.50      0.67      0.57         3
#           1       0.98      0.96      0.97        47
#
# avg / total       0.95      0.94      0.94        50
#
# roc_auc_score: 0.812057
#       name  importance
# 4  deleted    0.561657
# 3    added    0.438343
# Model.score: 0.800000
# accuracy_score: 0.800000
#              precision    recall  f1-score   support
#
#           0       0.78      0.47      0.58        15
#           1       0.80      0.94      0.87        35
#
# avg / total       0.80      0.80      0.78        50
#
# roc_auc_score: 0.704762
#       name  importance
# 4  deleted    0.589813
# 3    added    0.410187
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         8
#           1       0.91      1.00      0.95        42
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.750000
#       name  importance
# 4  deleted    0.584152
# 3    added    0.415848
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.62      0.77         8
#           1       0.93      1.00      0.97        42
#
# avg / total       0.94      0.94      0.93        50
#
# roc_auc_score: 0.812500
#       name  importance
# 4  deleted    0.597087
# 3    added    0.402913
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.80      0.67      0.73         6
#           1       0.96      0.98      0.97        44
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.821970
#       name  importance
# 4  deleted    0.572822
# 3    added    0.427178
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       1.00      0.45      0.62        11
#           1       0.87      1.00      0.93        39
#
# avg / total       0.90      0.88      0.86        50
#
# roc_auc_score: 0.727273
#       name  importance
# 4  deleted     0.56968
# 3    added     0.43032
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.60      0.75        10
#           1       0.91      1.00      0.95        40
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.800000
#       name  importance
# 4  deleted    0.575584
# 3    added    0.424416
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         8
#           1       0.91      1.00      0.95        42
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.750000
#       name  importance
# 4  deleted    0.581477
# 3    added    0.418523
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.80      0.89         5
#           1       0.98      1.00      0.99        45
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.900000
#       name  importance
# 4  deleted    0.586433
# 3    added    0.413567
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#       name  importance
# 4  deleted    0.584986
# 3    added    0.415014
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67        12
#           1       0.86      1.00      0.93        38
#
# avg / total       0.90      0.88      0.86        50
#
# roc_auc_score: 0.750000
#       name  importance
# 4  deleted    0.591206
# 3    added    0.408794
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       0.75      0.50      0.60         6
#           1       0.93      0.98      0.96        44
#
# avg / total       0.91      0.92      0.91        50
#
# roc_auc_score: 0.738636
#       name  importance
# 4  deleted    0.625343
# 3    added    0.374657
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       0.89      0.62      0.73        13
#           1       0.88      0.97      0.92        37
#
# avg / total       0.88      0.88      0.87        50
#
# roc_auc_score: 0.794179
#       name  importance
# 4  deleted    0.631819
# 3    added    0.368181
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       0.97      0.90      0.93        31
#           1       0.86      0.95      0.90        19
#
# avg / total       0.92      0.92      0.92        50
#
# roc_auc_score: 0.925297
#       name  importance
# 4  deleted    0.624849
# 3    added    0.375151
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.67      0.80         3
#           1       0.98      1.00      0.99        47
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.833333
#       name  importance
# 4  deleted     0.62589
# 3    added     0.37411
# Model.score: 0.740000
# accuracy_score: 0.740000
#              precision    recall  f1-score   support
#
#           0       1.00      0.07      0.13        14
#           1       0.73      1.00      0.85        36
#
# avg / total       0.81      0.74      0.65        50
#
# roc_auc_score: 0.535714
#       name  importance
# 4  deleted    0.618145
# 3    added    0.381855
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.86      0.75      0.80         8
#           1       0.95      0.98      0.96        42
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.863095
#       name  importance
# 4  deleted     0.62627
# 3    added     0.37373
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         6
#           1       0.94      1.00      0.97        44
#
# avg / total       0.94      0.94      0.93        50
#
# roc_auc_score: 0.750000
#       name  importance
# 4  deleted     0.61968
# 3    added     0.38032
# Model.score: 0.780000
# accuracy_score: 0.780000
#              precision    recall  f1-score   support
#
#           0       0.67      0.31      0.42        13
#           1       0.80      0.95      0.86        37
#
# avg / total       0.76      0.78      0.75        50
#
# roc_auc_score: 0.626819
#       name  importance
# 4  deleted    0.609194
# 3    added    0.390806
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.94      1.00      0.97        47
#
# avg / total       0.88      0.94      0.91        50
#
# roc_auc_score: 0.500000
#       name  importance
# 4  deleted    0.540377
# 3    added    0.459623
# Model.score: 0.840000
# accuracy_score: 0.840000
#              precision    recall  f1-score   support
#
#           0       1.00      0.62      0.76        21
#           1       0.78      1.00      0.88        29
#
# avg / total       0.87      0.84      0.83        50
#
# roc_auc_score: 0.809524
#       name  importance
# 4  deleted    0.539543
# 3    added    0.460457
# Model.score: 1.000000
# accuracy_score: 1.000000
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        14
#           1       1.00      1.00      1.00        36
#
# avg / total       1.00      1.00      1.00        50
#
# roc_auc_score: 1.000000
#       name  importance
# 0    added    0.591433
# 1  deleted    0.408567
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.82      0.90        17
#           1       0.92      1.00      0.96        33
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.911765
#       name  importance
# 1  deleted    0.553347
# 0    added    0.446653
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       0.92      0.92      0.92        13
#           1       0.97      0.97      0.97        37
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.948025
#       name  importance
# 1  deleted    0.616864
# 0    added    0.383136
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.78      0.88         9
#           1       0.95      1.00      0.98        41
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.888889
#       name  importance
# 1  deleted    0.527078
# 0    added    0.472922
# Model.score: 0.860000
# accuracy_score: 0.860000
#              precision    recall  f1-score   support
#
#           0       0.93      0.68      0.79        19
#           1       0.83      0.97      0.90        31
#
# avg / total       0.87      0.86      0.85        50
#
# roc_auc_score: 0.825976
#       name  importance
# 0    added    0.534016
# 1  deleted    0.465984
# Model.score: 0.840000
# accuracy_score: 0.840000
#              precision    recall  f1-score   support
#
#           0       1.00      0.43      0.60        14
#           1       0.82      1.00      0.90        36
#
# avg / total       0.87      0.84      0.82        50
#
# roc_auc_score: 0.714286
#       name  importance
# 0    added    0.627518
# 1  deleted    0.372482
# Model.score: 0.800000
# accuracy_score: 0.800000
#              precision    recall  f1-score   support
#
#           0       1.00      0.17      0.29        12
#           1       0.79      1.00      0.88        38
#
# avg / total       0.84      0.80      0.74        50
#
# roc_auc_score: 0.583333
#       name  importance
# 1  deleted    0.520525
# 0    added    0.479475
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.75      1.00      0.86         3
#           1       1.00      0.98      0.99        47
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.989362
#       name  importance
# 1  deleted    0.534185
# 0    added    0.465815
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       0.91      0.91      0.91        11
#           1       0.97      0.97      0.97        39
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.941725
#       name  importance
# 1  deleted    0.520082
# 0    added    0.479918
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         6
#           1       0.92      1.00      0.96        44
#
# avg / total       0.93      0.92      0.90        50
#
# roc_auc_score: 0.666667
#       name  importance
# 1  deleted    0.512987
# 0    added    0.487013
# Model.score: 1.000000
# accuracy_score: 1.000000
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         2
#           1       1.00      1.00      1.00        48
#
# avg / total       1.00      1.00      1.00        50
#
# roc_auc_score: 1.000000
#       name  importance
# 0    added    0.511264
# 1  deleted    0.488736
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#       name  importance
# 0    added    0.523626
# 1  deleted    0.476374
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         2
#           1       0.98      1.00      0.99        48
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.750000
#       name  importance
# 0    added    0.521544
# 1  deleted    0.478456
# Model.score: 1.000000
# accuracy_score: 1.000000
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00         1
#           1       1.00      1.00      1.00        49
#
# avg / total       1.00      1.00      1.00        50
#
# roc_auc_score: 1.000000
#       name  importance
# 0    added    0.515948
# 1  deleted    0.484052
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.98      1.00      0.99        49
#
# avg / total       0.96      0.98      0.97        50
#
# roc_auc_score: 0.500000
#       name  importance
# 0    added    0.525323
# 1  deleted    0.474677
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         2
#           1       0.98      1.00      0.99        48
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.750000
#       name  importance
# 0    added    0.613753
# 1  deleted    0.386247
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.79      0.88        14
#           1       0.92      1.00      0.96        36
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.892857
#       name  importance
# 0    added    0.549444
# 1  deleted    0.450556
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.85      0.92        13
#           1       0.95      1.00      0.97        37
#
# avg / total       0.96      0.96      0.96        50
#
# roc_auc_score: 0.923077
#       name  importance
# 1  deleted    0.525426
# 0    added    0.474574
# Model.score: 0.840000
# accuracy_score: 0.840000
#              precision    recall  f1-score   support
#
#           0       0.75      0.30      0.43        10
#           1       0.85      0.97      0.91        40
#
# avg / total       0.83      0.84      0.81        50
#
# roc_auc_score: 0.637500
#       name  importance
# 1  deleted    0.540762
# 0    added    0.459238
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       0.67      1.00      0.80         2
#           1       1.00      0.98      0.99        48
#
# avg / total       0.99      0.98      0.98        50
#
# roc_auc_score: 0.989583
#       name  importance
# 0    added    0.511304
# 1  deleted    0.488696
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#       name  importance
# 0    added    0.508575
# 1  deleted    0.491425
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.67      0.80         3
#           1       0.98      1.00      0.99        47
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.833333
#       name  importance
# 0    added    0.507895
# 1  deleted    0.492105
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         3
#           1       0.96      1.00      0.98        47
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.666667
#       name  importance
# 0    added    0.503881
# 1  deleted    0.496119
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.33      0.50         6
#           1       0.92      1.00      0.96        44
#
# avg / total       0.93      0.92      0.90        50
#
# roc_auc_score: 0.666667
#       name  importance
# 0    added    0.500056
# 1  deleted    0.499944
# Model.score: 0.900000
# accuracy_score: 0.900000
#              precision    recall  f1-score   support
#
#           0       1.00      0.17      0.29         6
#           1       0.90      1.00      0.95        44
#
# avg / total       0.91      0.90      0.87        50
#
# roc_auc_score: 0.583333
#       name  importance
# 1  deleted    0.507929
# 0    added    0.492071
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.50      0.67      0.57         3
#           1       0.98      0.96      0.97        47
#
# avg / total       0.95      0.94      0.94        50
#
# roc_auc_score: 0.812057
#       name  importance
# 1  deleted    0.561657
# 0    added    0.438343
# Model.score: 0.800000
# accuracy_score: 0.800000
#              precision    recall  f1-score   support
#
#           0       0.78      0.47      0.58        15
#           1       0.80      0.94      0.87        35
#
# avg / total       0.80      0.80      0.78        50
#
# roc_auc_score: 0.704762
#       name  importance
# 1  deleted    0.589813
# 0    added    0.410187
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         8
#           1       0.91      1.00      0.95        42
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.750000
#       name  importance
# 1  deleted    0.584152
# 0    added    0.415848
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.62      0.77         8
#           1       0.93      1.00      0.97        42
#
# avg / total       0.94      0.94      0.93        50
#
# roc_auc_score: 0.812500
#       name  importance
# 1  deleted    0.597087
# 0    added    0.402913
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.80      0.67      0.73         6
#           1       0.96      0.98      0.97        44
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.821970
#       name  importance
# 1  deleted    0.572822
# 0    added    0.427178
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       1.00      0.45      0.62        11
#           1       0.87      1.00      0.93        39
#
# avg / total       0.90      0.88      0.86        50
#
# roc_auc_score: 0.727273
#       name  importance
# 1  deleted     0.56968
# 0    added     0.43032
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.60      0.75        10
#           1       0.91      1.00      0.95        40
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.800000
#       name  importance
# 1  deleted    0.575584
# 0    added    0.424416
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         8
#           1       0.91      1.00      0.95        42
#
# avg / total       0.93      0.92      0.91        50
#
# roc_auc_score: 0.750000
#       name  importance
# 1  deleted    0.581477
# 0    added    0.418523
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.80      0.89         5
#           1       0.98      1.00      0.99        45
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.900000
#       name  importance
# 1  deleted    0.586433
# 0    added    0.413567
# Model.score: 0.960000
# accuracy_score: 0.960000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         4
#           1       0.96      1.00      0.98        46
#
# avg / total       0.96      0.96      0.95        50
#
# roc_auc_score: 0.750000
#       name  importance
# 1  deleted    0.584986
# 0    added    0.415014
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67        12
#           1       0.86      1.00      0.93        38
#
# avg / total       0.90      0.88      0.86        50
#
# roc_auc_score: 0.750000
#       name  importance
# 1  deleted    0.591206
# 0    added    0.408794
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       0.75      0.50      0.60         6
#           1       0.93      0.98      0.96        44
#
# avg / total       0.91      0.92      0.91        50
#
# roc_auc_score: 0.738636
#       name  importance
# 1  deleted    0.625343
# 0    added    0.374657
# Model.score: 0.880000
# accuracy_score: 0.880000
#              precision    recall  f1-score   support
#
#           0       0.89      0.62      0.73        13
#           1       0.88      0.97      0.92        37
#
# avg / total       0.88      0.88      0.87        50
#
# roc_auc_score: 0.794179
#       name  importance
# 1  deleted    0.631819
# 0    added    0.368181
# Model.score: 0.920000
# accuracy_score: 0.920000
#              precision    recall  f1-score   support
#
#           0       0.97      0.90      0.93        31
#           1       0.86      0.95      0.90        19
#
# avg / total       0.92      0.92      0.92        50
#
# roc_auc_score: 0.925297
#       name  importance
# 1  deleted    0.624849
# 0    added    0.375151
# Model.score: 0.980000
# accuracy_score: 0.980000
#              precision    recall  f1-score   support
#
#           0       1.00      0.67      0.80         3
#           1       0.98      1.00      0.99        47
#
# avg / total       0.98      0.98      0.98        50
#
# roc_auc_score: 0.833333
#       name  importance
# 1  deleted     0.62589
# 0    added     0.37411
# Model.score: 0.740000
# accuracy_score: 0.740000
#              precision    recall  f1-score   support
#
#           0       1.00      0.07      0.13        14
#           1       0.73      1.00      0.85        36
#
# avg / total       0.81      0.74      0.65        50
#
# roc_auc_score: 0.535714
#       name  importance
# 1  deleted    0.618145
# 0    added    0.381855
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.86      0.75      0.80         8
#           1       0.95      0.98      0.96        42
#
# avg / total       0.94      0.94      0.94        50
#
# roc_auc_score: 0.863095
#       name  importance
# 1  deleted     0.62627
# 0    added     0.37373
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       1.00      0.50      0.67         6
#           1       0.94      1.00      0.97        44
#
# avg / total       0.94      0.94      0.93        50
#
# roc_auc_score: 0.750000
#       name  importance
# 1  deleted     0.61968
# 0    added     0.38032
# Model.score: 0.780000
# accuracy_score: 0.780000
#              precision    recall  f1-score   support
#
#           0       0.67      0.31      0.42        13
#           1       0.80      0.95      0.86        37
#
# avg / total       0.76      0.78      0.75        50
#
# roc_auc_score: 0.626819
#       name  importance
# 1  deleted    0.609194
# 0    added    0.390806
# Model.score: 0.940000
# accuracy_score: 0.940000
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.94      1.00      0.97        47
#
# avg / total       0.88      0.94      0.91        50
#
# roc_auc_score: 0.500000
#       name  importance
# 1  deleted    0.540377
# 0    added    0.459623
# Model.score: 0.840000
# accuracy_score: 0.840000
#              precision    recall  f1-score   support
#
#           0       1.00      0.62      0.76        21
#           1       0.78      1.00      0.88        29
#
# avg / total       0.87      0.84      0.83        50
#
# roc_auc_score: 0.809524
#       name  importance
# 1  deleted    0.539543
# 0    added    0.460457

# %% [markdown]
# ### Results of this step are omitted for printing. However, the large cross-validation can be run to see them.

# %% [markdown]
# ### The individual data sets used for training and testing are quite small and imbalanced.
#
# ### Many of the same relationships still show up.
#
# ### Why is 'added' a much more important factor than 'deleted'?

# %%
print "Mean", metricsData['data']['netchurn'].mean()
print "Variance", metricsData['data']['netchurn'].var()
print "Standard deviation", metricsData['data']['netchurn'].std()
print "Max", metricsData['data']['netchurn'].max()
print "Min", metricsData['data']['netchurn'].min()
# Out:
# Mean -5.468386023294509
# Variance 12577.661505342396
# Standard deviation 112.15017389795878
# Max 996
# Min -2190

# %% [markdown]
# ### This codebase is *growing* in general (more added than deleted)
#
# ### Some files must experience more churn than others. We know from some of the motivating literature that defects can be correlated with large pre-release churn.
#
# ### Let's make some categories of binned churn data and classify them

# %%
#churnBinnedCategories = ['churnLow','churnMedium','churnHigh','churnHigher','churnHighest']
churnBinnedCategories = ['churnLow','churnMedium','churnHigh', 'churnHighest']
dataSetUpdated = toolkit.utilities.addBinnedResponseCategory(metricsData['data'], 'netchurn', churnBinnedCategories)

# %%
from sklearn.tree import DecisionTreeClassifier
modelInstance = DecisionTreeClassifier(max_leaf_nodes=8, criterion='entropy')
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, churnBinnedCategories, modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMedium', 'churnHigh', 'churnHighest']
# Model.score: 0.987510
# accuracy_score: 0.987510
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.38      1.00      0.55         3
#           2       1.00      0.99      0.99      1186
#           3       0.55      0.50      0.52        12
#
# avg / total       0.99      0.99      0.99      1201
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# roc_auc_score cannot be computed for this test set
#               name  importance
# 4          deleted    0.477736
# 3            added    0.426877
# 22    staticFields    0.048103
# 32         loopQty    0.030212
# 15  privateMethods    0.017072
# Model.score: 0.987510
# accuracy_score: 0.987510
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.38      1.00      0.55         3
#           2       1.00      0.99      0.99      1186
#           3       0.55      0.50      0.52        12
#
# avg / total       0.99      0.99      0.99      1201
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 1  deleted    0.546291
# 0    added    0.453709

# %% [markdown]
# ### Now we're seeing something interesting. The vast majority of the files exhibit very low amounts of churn. A select few files receive most of the lines added/deleted. Does the class imbalance impact the validity of this model? Let's try more cross-validation to see.

# %%
folds = 3
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, folds, churnBinnedCategories, modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMedium', 'churnHigh', 'churnHighest']
# Model.score: 0.986250
# accuracy_score: 0.986250
#              precision    recall  f1-score   support
#
#           0       0.50      1.00      0.67         1
#           1       0.40      0.67      0.50         3
#           2       0.99      0.99      0.99       784
#           3       0.70      0.58      0.64        12
#
# avg / total       0.99      0.99      0.99       800
#
# roc_auc_score: 0.873100
#             name  importance
# 4        deleted    0.492045
# 3          added    0.268978
# 30           loc    0.098369
# 22  staticFields    0.091424
# 6            soc    0.049184
# Model.score: 0.993750
# accuracy_score: 0.993750
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      1.00      1.00         3
#           2       0.99      1.00      1.00       788
#           3       0.83      0.56      0.67         9
#
# avg / total       0.99      0.99      0.99       800
#
# roc_auc_score cannot be computed for this test set
#                  name  importance
# 3               added    0.484268
# 4             deleted    0.471191
# 36  stringLiteralsQty    0.044541
# Model.score: 0.985000
# accuracy_score: 0.985000
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.43      1.00      0.60         3
#           2       1.00      0.99      0.99       784
#           3       0.62      0.67      0.64        12
#
# avg / total       0.99      0.98      0.99       800
#
# roc_auc_score: 0.807359
#       name  importance
# 1  deleted    0.687014
# 0    added    0.312986
# Model.score: 0.991250
# accuracy_score: 0.991250
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.75      1.00      0.86         3
#           2       0.99      1.00      1.00       788
#           3       0.71      0.56      0.63         9
#
# avg / total       0.99      0.99      0.99       800
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 1  deleted    0.540164
# 0    added    0.459836

# %% [markdown]
# ### Let's look at this from another point of view. What characterises the files which have the most lines added?

# %%
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsData['data'], 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.945878
# accuracy_score: 0.945878
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96       890
#           1       0.93      0.85      0.89       311
#
# avg / total       0.95      0.95      0.95      1201
#
# roc_auc_score: 0.915371
#        name  importance
# 6  netchurn    0.626919
# 3   deleted    0.342857
# 2    n-revs    0.030223
# Model.score: 0.899251
# accuracy_score: 0.899251
#              precision    recall  f1-score   support
#
#           0       0.92      0.94      0.93       890
#           1       0.83      0.77      0.80       311
#
# avg / total       0.90      0.90      0.90      1201
#
# roc_auc_score: 0.856716
#        name  importance
# 2  netchurn     0.65617
# 1   deleted     0.34383

# %% [markdown]
# ### Net churn and deleted lines are strongly related. What do we find if we're not allowed to use these in our decision tree?

# %%
alteredData = metricsData['data'].drop(['netchurn','deleted'], axis=1)
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData, 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.822648
# accuracy_score: 0.822648
#              precision    recall  f1-score   support
#
#           0       0.87      0.90      0.88       890
#           1       0.68      0.60      0.64       311
#
# avg / total       0.82      0.82      0.82      1201
#
# roc_auc_score: 0.750643
#                  name  importance
# 2              n-revs    0.714335
# 34  stringLiteralsQty    0.116380
# 10       totalMethods    0.075152
# 43     uniqueWordsQty    0.049702
# 31     comparisonsQty    0.044430
# Model.score: 0.835137
# accuracy_score: 0.835137
#              precision    recall  f1-score   support
#
#           0       0.82      0.99      0.90       890
#           1       0.92      0.40      0.56       311
#
# avg / total       0.85      0.84      0.81      1201
#
# roc_auc_score: 0.693177
#                 name  importance
# 0             n-revs    0.852311
# 3  stringLiteralsQty    0.147689

# %% [markdown]
# ### The model uses n-revs as the most important feature, but it does not classify '# lines added above the mean' very well

# %%
alteredData2 = metricsData['data'].drop(['netchurn','deleted','n-revs'], axis=1)
addedModel2 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData2, 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.773522
# accuracy_score: 0.773522
#              precision    recall  f1-score   support
#
#           0       0.79      0.96      0.86       890
#           1       0.67      0.25      0.36       311
#
# avg / total       0.75      0.77      0.73      1201
#
# roc_auc_score: 0.603492
#                  name  importance
# 2       fractal-value    0.505913
# 35     assignmentsQty    0.137002
# 1           n-authors    0.096776
# 3                 soc    0.084943
# 44               time    0.080965
# 33  stringLiteralsQty    0.047846
# 0          age-months    0.046555
# Model.score: 0.764363
# accuracy_score: 0.764363
#              precision    recall  f1-score   support
#
#           0       0.77      0.98      0.86       890
#           1       0.70      0.16      0.26       311
#
# avg / total       0.75      0.76      0.70      1201
#
# roc_auc_score: 0.566980
#              name  importance
# 1       n-authors    0.814785
# 5  assignmentsQty    0.185215

# %% [markdown]
# ### n-authors has similar problems with identifying the minority class

# %%
alteredData3 = metricsData['data'].drop(['netchurn','deleted','n-revs','n-authors'], axis=1)
addedModel3 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData3, 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.761032
# accuracy_score: 0.761032
#              precision    recall  f1-score   support
#
#           0       0.76      0.98      0.86       890
#           1       0.69      0.14      0.23       311
#
# avg / total       0.75      0.76      0.70      1201
#
# roc_auc_score: 0.558458
#               name  importance
# 1    fractal-value    0.502635
# 43            time    0.138076
# 34  assignmentsQty    0.136114
# 10   publicMethods    0.092528
# 2              soc    0.084393
# 0       age-months    0.046253
# Model.score: 0.761032
# accuracy_score: 0.761032
#              precision    recall  f1-score   support
#
#           0       0.76      0.98      0.86       890
#           1       0.69      0.14      0.23       311
#
# avg / total       0.75      0.76      0.70      1201
#
# roc_auc_score: 0.558458
#              name  importance
# 1   fractal-value    0.687339
# 4  assignmentsQty    0.186132
# 3   publicMethods    0.126529

# %% [markdown]
# ### fractal-value is derived from n-revs and n-authors
#
# ### Let's get rid of it and build a regression model for nline
# ### This model will predict the sizes of files based on their other static features

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=8)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
alteredData4 = metricsData['data'].drop(['netchurn','deleted','n-revs','n-authors','fractal-value'], axis=1)
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was nline
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4485169078a5> in <module>()
#       3 modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
#       4 alteredData4 = metricsData['data'].drop(['netchurn','deleted','n-revs','n-authors','fractal-value'], axis=1)
# ----> 5 nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /home/jovyan/work/toolkit/modelRefinement.pyc in makeAndUpdateModel(studyDirectory, data, folds, responseVariable, model, modelRefined, categoryFunction, scoreOnly, visualize)
#      13 def makeAndUpdateModel(studyDirectory, data, folds, responseVariable, model, modelRefined=None, categoryFunction=None, scoreOnly=True, visualize=False):
#      14     import modelAnalysis as analysis
# ---> 15     timeModel = analysis.timeSeriesModel(data, folds, responseVariable, model, categoryFunction, scoreOnly)
#      16     return updateModel(studyDirectory, timeModel['data']['features'], timeModel['data']['names'],
#      17                         timeModel['data']['response'], folds, timeModel['fittedModel'],
#
# /home/jovyan/work/toolkit/modelAnalysis.pyc in timeSeriesModel(data, CVfolds, responseVariable, model, useScaler, scoreOnly, categoryFunction)
#      60
#      61         import dataGathering
# ---> 62         timeData = dataGathering.processTimeData(data, model, responseVariable, useScaler, categoryFunction)
#      63         fittedModel = timeSeriesCV(timeData['features'], timeData['names'], timeData['response'], CVfolds, model, scoreOnly)
#      64         return dict(fittedModel = fittedModel, data = timeData)
#
# /home/jovyan/work/toolkit/dataGathering.pyc in processTimeData(timeData, model, responseVariable, useScaler, categoryFunction)
#      11                 response = categoryFunction(timeData[responseVariable]).astype(int)
#      12         else:
# ---> 13                 response = timeData[responseVariable]
#      14
#      15         features = timeData.copy(deep=True)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nline'

# %% [markdown]
# ### We see that the number of indented lines is a very good predictor of the number of lines
#
# ### Is the model using indent_lines because it is correlated with nline?

# %%
# We use the Spearman measure of rank correlation
metricsData['data']['nline'].corr(metricsData['data']['indent_lines'], method='spearman')

# %% [markdown]
# ### Let's remove indent_lines from this data set
# ### Are we still able to regress on nline (and with high performance)?

# %%
alteredData5 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier'], axis=1)
nlineModelR2 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData5, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-f3769c2d09dc> in <module>()
# ----> 1 alteredData5 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier'], axis=1)
#       2 nlineModelR2 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData5, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['indent_lines' 'nchar' 'nstatement' 'nidentifier'] not found in axis"

# %% [markdown]
# ### cqmetrics provides several measures of the 'number of functions' contained in a file (each calculated differently)
#
# ### The model uses these to predict the size of files

# %%
alteredData6 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier', 'nfunction','nfunction2','nfunction3'], axis=1)
nlineModelR3 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData6, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1cbb1675fd5f> in <module>()
# ----> 1 alteredData6 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier', 'nfunction','nfunction2','nfunction3'], axis=1)
#       2 nlineModelR3 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData6, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['indent_lines' 'nchar' 'nstatement' 'nidentifier' 'nfunction'\n 'nfunction2' 'nfunction3'] not found in axis"

# %%
alteredData7 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier', 'nfunction','nfunction2','nfunction3', 'unique_nidentifier'], axis=1)
nlineModelR4 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData7, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-1dd5db77224d> in <module>()
# ----> 1 alteredData7 = metricsData['data'].drop(['indent_lines','nchar','nstatement','nidentifier', 'nfunction','nfunction2','nfunction3', 'unique_nidentifier'], axis=1)
#       2 nlineModelR4 = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData7, 2, 'nline', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['indent_lines' 'nchar' 'nstatement' 'nidentifier' 'nfunction'\n 'nfunction2' 'nfunction3' 'unique_nidentifier'] not found in axis"

# %% [markdown]
# ### Our regression model of nline needs the number of (unique) identifiers, and the number of functions in a file to explain the variance in our dataset
#
# ### Without these features, the model rapidly loses accuracy.
#
# ### From all the features we measure, the only ones which are strong predictors of size are other measures of such (which are bound to be correlated - lines of source code necessarily add identifiers, operators, functions etc as counted by Halstead's metrics)
#
# ### We see that the maximum Halstead complexity metric among the functions in each file is a (weak) predictor under this model. The measures from which it is calculated have a much stronger correlation with size.
#
# ### What about modelling these measures of complexity?

# %%
cycloData = metricsData['data'].drop(['cyclomatic_sd', 'cyclomatic_mean'], axis=1)
cycloModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, cycloData, 2, 'cyclomatic_max', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-62b805fa575b> in <module>()
# ----> 1 cycloData = metricsData['data'].drop(['cyclomatic_sd', 'cyclomatic_mean'], axis=1)
#       2 cycloModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, cycloData, 2, 'cyclomatic_max', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['cyclomatic_sd' 'cyclomatic_mean'] not found in axis"

# %% [markdown]
# ### Cyclomatic complexity seems to be similar to Halstead complexity for our dataset
# ### The measures which are used to derive both of these are also predictors. Let's remove them and repeat..

# %%
cycloData2 = metricsData['data'].drop(['halstead_sd','nidentifier','halstead_mean','halstead_min','cyclomatic_sd', 'cyclomatic_mean', 'halstead_max','nstatement','statement_nesting_mean'], axis=1)
cycloModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, cycloData2, 2, 'cyclomatic_max', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-7cfec916e7ba> in <module>()
# ----> 1 cycloData2 = metricsData['data'].drop(['halstead_sd','nidentifier','halstead_mean','halstead_min','cyclomatic_sd', 'cyclomatic_mean', 'halstead_max','nstatement','statement_nesting_mean'], axis=1)
#       2 cycloModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, cycloData2, 2, 'cyclomatic_max', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['halstead_sd' 'nidentifier' 'halstead_mean' 'halstead_min'\n 'cyclomatic_sd' 'cyclomatic_mean' 'halstead_max' 'nstatement'\n 'statement_nesting_mean'] not found in axis"

# %% [markdown]
# ### The number of static variables and the mean indentation level of files are strong predictors of cyclomatic complexity for our dataset
#
# ### This indentation predictor is similar to the findings of Hindle.
# ### What about the 'ninternal' (static linkage) result? The files containing functions with higher cyclomatic complexity also have more variables (which are shared between functions in the same file)?
# ### This may be starting to give some insight into our codebase. Perhaps our code overuses file-global variables together with functions which are difficult to test.
#
# ### Can we model indentation? What leads to 'wider' files?

# %%
indentData = metricsData['data'].drop(['indent_sd','indent_median','indent_max','indent_lines'],axis=1)
indentModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, indentData, 2, 'indent_mean', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-def7b202ac80> in <module>()
# ----> 1 indentData = metricsData['data'].drop(['indent_sd','indent_median','indent_max','indent_lines'],axis=1)
#       2 indentModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, indentData, 2, 'indent_mean', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/generic.pyc in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['indent_sd' 'indent_median' 'indent_max' 'indent_lines'] not found in axis"

# %% [markdown]
# ### The files with more nesting (which drives Halstead's complexity) are more indented
#
# ### This tells us that our codebase uses indentation to *indicate* nesting frequently. This is typical in C programming, of course. However, there is value in this seemingly simple result: to locate the files with high syntax-driven measures of complexity in this codebase, we can use a heuristic like the level of indentation instead.
#
# ### It is important to also consider that our dataset does not have other measures of complexity which have *not* been represented by this model.  Halstead and McCabe's measures are dominant in the measurement of C programs, but other measures of complexity which are not strongly connected with structural *nesting* may not be predicted by indentation. In other words, indentation does not necessarily predict *complexity* - it predicts *Halstead and McCabe complexity*.

# %%
indentModelC = toolkit.refinement.makeAndUpdateModel(rootDirectory, indentData, 2, 'indent_mean', modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-c654d91a6cbe> in <module>()
# ----> 1 indentModelC = toolkit.refinement.makeAndUpdateModel(rootDirectory, indentData, 2, 'indent_mean', modelInstance, modelSimpler, visualize=False, scoreOnly=False)
#
# NameError: name 'indentData' is not defined

# %% [markdown]
# ### We can use the DecisionTreeClassifier to bin samples above and below the mean indentation level, more effectively than we can predict the indentation level itself via regression.
#
# ### To what degree is this true? Let's try adding more categories as before.

# %%
indentBinnedCategories = ['iLow','iMedium','iHigh','iVeryHigh']
dataSetUpdated = toolkit.utilities.addBinnedResponseCategory(indentData, 'indent_mean', indentBinnedCategories)
indentModelC = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, indentBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)

# %% [markdown]
# ### This model suffers from class imbalance: with only 8 leaves, it loses accuracy when predicting the files with the most indentation. This is a common issue with decision trees being exposed by our dataset. It is not a property of our codebase or of C source code.
#
# ### In this case, we can use an *ensemble model* to make up for the loss of accuracy in the minority class. However, we do so at the expense of model interpretation.
#
# ### We build a random forest: a group of decision trees are made with the first decision chosen at random. The group of trees is used to classify each sample, and a majority voting scheme decides the model output.
#
# ### This has the effect of creating more trees. Some may resemble the above single tree (which accurately modelled *most* of our data). Others may be highly inaccurate, except for small subsets of the data.
#
# ### The training of this model is 'embarassingly parallel': we use all the available CPU cores in parallel to create our decision trees.
#
# ### Forest models can be difficult to tune, and to interpret. We omit visualization of the many trees. For automated classification tasks used in a production environment (as opposed to empirical research), forests may be valuable despite their lack of interpretability.

# %%
# For parallel construction of forest models
import psutil
cores = psutil.cpu_count()

from sklearn.ensemble import RandomForestClassifier
# We build a forest of n_estimators trees, with no restriction on the breadth/depth of trees.
modelCF = RandomForestClassifier(n_estimators=500, criterion='entropy', n_jobs=cores)
modelCFsimpler = RandomForestClassifier(n_estimators=20, max_leaf_nodes=2, criterion='entropy', n_jobs=cores) # Each tree makes one decision
updatedModelCF = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, indentBinnedCategories, modelCF, modelCFsimpler, scoreOnly=False, visualize=False)

# %% [markdown]
# ### The resulting forest together uses many features. Many of these are named entities - our trees are individually modelling the files in our codebase. This showcases a possible threat to the use of forest models with our dataset: there may be a tendency to model the one-hot encoded entities.
#
# ### We also note that the minority class is predicted with high Precision, but low Recall. From the high-indentation files we predict, they are predicted correctly. However, most of the high-indentation files are missed even by this model. The F1-Score (the harmonic mean of Precision and Recall) is similarly low.
#
# ### Since the training of a random forest includes random choices (the initial splits in each tree), the results of this cell may vary each time it is run. The models before and after the update are likely to differ.

# %% [markdown]
# ### In this case study, we have used the toolkit to do the following:
# - Gather the Git dataset
# - Create classification models of net churn: above and below the mean, in five binned categories
# - Create regression models of file size and cyclomatic complexity
# - Create regression and classification models of mean indentation
#     - Including a brief test of random forests to improve classification performance with a very small minority class we wish to predict: the files with the highest mean indentation level
