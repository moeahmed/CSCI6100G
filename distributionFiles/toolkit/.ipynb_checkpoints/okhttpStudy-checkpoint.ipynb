# %%
import toolkit

# %% [markdown]
# ### First, we gather the dataset. This is a history of Java static code metrics and change metrics for our project.

# %%
# Used to indicate where the data should be gathered and stored

rootDirectory = '../dataSets/okhttpStudy/'
# Call gatherTimeMetrics and measure Java, Indent and Change metrics 
# on .java files from the git project's repository


# Call gatherTimeMetrics and measure Java and change metrics 
# on .java files from the git project's repository
metricsDataMaven = toolkit.data.gatherTimeMetrics(rootDirectory, 'https://github.com/square/okhttp.git', rootDirectory+'okhttp/', '*/*.java *.java', ['java'], skipEvery=50)

# %%
metricsDataMaven['data']
# Out:
#                                                entity  age-months  n-authors  \
# 0   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 1   okhttp-sse/src/test/java/okhttp3/internal/sse/...           0          2
# 2   okhttp/src/test/java/okhttp3/internal/http2/Ht...           0          2
# 3         okhttp/src/test/java/okhttp3/CacheTest.java           1          3
# 4   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           1          2
# 5   okhttp/src/test/java/okhttp3/EventListenerTest...           1          3
# 6   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           1          2
# 7          okhttp/src/test/java/okhttp3/CallTest.java           1          4
# 8    okhttp/src/test/java/okhttp3/DispatcherTest.java           1          2
# 9   okhttp/src/test/java/okhttp3/internal/connecti...           1          3
# 10       okhttp/src/test/java/okhttp3/DuplexTest.java           1          2
# 11      okhttp/src/test/java/okhttp3/CookiesTest.java           2          1
# 12  okhttp/src/test/java/okhttp3/InterceptorTest.java           2          1
# 13  okhttp/src/test/java/okhttp3/URLConnectionTest...           2          1
# 14  okhttp/src/test/java/okhttp3/WholeOperationTim...           2          2
# 15  okhttp/src/test/java/okhttp3/internal/tls/Clie...           2          2
# 16  okhttp/src/test/java/okhttp3/ConnectionReuseTe...           2          1
# 17  okhttp-testing-support/src/main/java/okhttp3/T...           3          1
# 0   okhttp/src/test/java/okhttp3/ConnectionCoalesc...           4          2
# 1   okhttp/src/test/java/okhttp3/EventListenerTest...           4          2
# 2   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 3   okhttp/src/test/java/okhttp3/internal/ws/WebSo...           4          2
# 4   samples/guide/src/main/java/okhttp3/recipes/Pr...           4          1
# 5   okhttp/src/test/java/okhttp3/internal/http2/Ht...           4          3
# 6   okhttp-logging-interceptor/src/test/java/okhtt...           4          3
# 7   okhttp/src/test/java/okhttp3/URLConnectionTest...           4          3
# 8   okhttp/src/test/java/okhttp3/RecordingEventLis...           4          1
# 9        okhttp/src/test/java/okhttp3/DuplexTest.java           4          2
# 10  okhttp/src/test/java/okhttp3/internal/platform...           5          1
# 11  okhttp/src/test/java/okhttp3/internal/ws/WebSo...           5          2
# ..                                                ...         ...        ...
# 34  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 35  src/main/java/com/squareup/okhttp/internal/net...          83          1
# 36  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 37  src/test/java/com/squareup/okhttp/internal/io/...          83          1
# 38  src/test/java/com/squareup/okhttp/internal/net...          83          1
# 0   src/main/java/com/squareup/okhttp/OkHttpConnec...          84          1
# 1   src/main/java/libcore/net/http/HttpTransport.java          84          1
# 2   src/main/java/com/squareup/okhttp/OkHttpsConne...          84          2
# 3   src/main/java/libcore/util/ExtendedResponseCac...          84          2
# 4   src/main/java/libcore/net/http/HttpURLConnecti...          84          2
# 5   src/main/java/libcore/net/http/HttpResponseCac...          84          3
# 6   src/main/java/libcore/net/http/HttpsURLConnect...          84          2
# 7   src/test/java/libcore/net/http/URLConnectionTe...          84          3
# 8      src/main/java/libcore/net/http/HttpEngine.java          84          2
# 9   src/test/java/libcore/net/http/ExternalSpdyExa...          84          1
# 10   src/main/java/libcore/net/http/HeaderParser.java          85          2
# 11  src/main/java/libcore/net/http/RetryableOutput...          85          1
# 12  src/main/java/libcore/net/http/HttpConnection....          85          1
# 13  src/main/java/libcore/net/http/HttpConnectionP...          85          1
# 14      src/main/java/libcore/net/http/Challenge.java          85          1
# 15     src/main/java/libcore/net/http/RawHeaders.java          85          1
# 16     src/main/java/libcore/net/spdy/SpdyWriter.java          85          2
# 17            src/main/java/libcore/util/Libcore.java          85          1
# 18  src/main/java/libcore/net/spdy/SpdyConnection....          86          1
# 19     src/main/java/libcore/net/spdy/SpdyStream.java          86          1
# 20   src/test/java/libcore/net/spdy/MockSpdyPeer.java          86          1
# 21     src/main/java/libcore/net/spdy/SpdyServer.java          86          1
# 22     src/main/java/libcore/net/spdy/SpdyReader.java          86          1
# 23  src/test/java/libcore/net/spdy/SpdyConnectionT...          86          1
# 24  src/main/java/libcore/net/http/ResponseHeaders...          86          1
#
#     n-revs  added  deleted  fractal-value  soc  netchurn  cbo  ...  \
# 0        6     90       61           0.28    8        29   34  ...
# 1        2      3        8           0.50   12        -5   12  ...
# 2        6    128        6           0.44   14       122   86  ...
# 3        4     43        9           0.63    7        34   37  ...
# 4        2    105        7           0.50    6        98   20  ...
# 5        4      8       18           0.63   28       -10   68  ...
# 6        4     17       17           0.50   24         0   40  ...
# 7       10     95       19           0.64   32        76  118  ...
# 8        2      5        6           0.50   16        -1   16  ...
# 9        6     49       22           0.50    8        27   13  ...
# 10       3      5        5           0.44   23         0   27  ...
# 11       1      1        6           0.00   10        -5   15  ...
# 12       2     13       11           0.00   10         2   41  ...
# 13       1      1        2           0.00   10        -1  120  ...
# 14       2      6        7           0.50   10        -1   23  ...
# 15       2      5        0           0.50    9         5   14  ...
# 16       1      1        6           0.00   10        -5   18  ...
# 17       1     12        0           0.00    7        12    2  ...
# 0        4      3       18           0.38   40       -15   21  ...
# 1        6     44       28           0.44   81        16   68  ...
# 2        1      9        0           0.00    6         9   21  ...
# 3        5     34       25           0.48   47         9   37  ...
# 4        1      9        0           0.00    6         9   13  ...
# 5        8     58       56           0.59   68         2   86  ...
# 6        4     17        7           0.63   37        10   21  ...
# 7        9     37       28           0.64   84         9  120  ...
# 8        1     27        0           0.00    6        27  104  ...
# 9        3      8        8           0.44   42         0   27  ...
# 10       1      1        1           0.00   14         0    4  ...
# 11       3      5        4           0.44   27         1    8  ...
# ..     ...    ...      ...            ...  ...       ...  ...  ...
# 34       2      4       44           0.00   17       -40    1  ...
# 35       3     30        8           0.00   18        22    9  ...
# 36       2    252      270           0.00   15       -18   22  ...
# 37       1     61       87           0.00   12       -26    6  ...
# 38       1      5        4           0.00   12         1    2  ...
# 0        1      0      829           0.00   11      -829    3  ...
# 1        6     70      109           0.00   33       -39   40  ...
# 2        2      0      300           0.50   15      -300    2  ...
# 3        2      5        3           0.50   18         2    2  ...
# 4        8     84      116           0.22   42       -32   13  ...
# 5        6     43       45           0.50   24        -2   41  ...
# 6        4     31      104           0.38   27       -73   28  ...
# 7       14    563      216           0.26   55       347   45  ...
# 8        8     72       50           0.22   48        22   15  ...
# 9        1      3        3           0.00   11         0    2  ...
# 10       2      2       54           0.50   13       -52    4  ...
# 11       1      5        4           0.00    9         1    4  ...
# 12       6    323      326           0.00   32        -3   16  ...
# 13       2      3       10           0.00   13        -7    4  ...
# 14       1      0       40           0.00   11       -40    1  ...
# 15       4     76       33           0.00   28        43    2  ...
# 16       6     96       62           0.28   22        34    2  ...
# 17       3      5      153           0.00   14      -148    8  ...
# 18       9    452      343           0.00   34       109   18  ...
# 19       4    127       76           0.00   12        51   13  ...
# 20       4     79       20           0.00   19        59   10  ...
# 21       2     12        6           0.00    7         6    5  ...
# 22       7    119       74           0.00   29        45    6  ...
# 23       8    536      113           0.00   32       423    9  ...
# 24       1      2        1           0.00    7         1    9  ...
#
#    assignmentsQty mathOperationsQty variablesQty maxNestedBlocks  \
# 0             262                12          261               3
# 1              12                 3           10               0
# 2             231                 7          214               8
# 3             295               136          282               1
# 4              34                 0           32               1
# 5             154                11          141               5
# 6              89                 8           82               2
# 7             435                35          377              10
# 8              36                 0           36               2
# 9              28                 0           28               1
# 10             70                 0           64               2
# 11             63                 9           55               2
# 12            136                12          142               5
# 13            390                45          329               5
# 14             36                 1           36               3
# 15             41                 0           40               1
# 16             53                 0           48               1
# 17              5                 2            4               1
# 0              36                 0           32               1
# 1             155                11          141               5
# 2              11                 2           11               2
# 3              88                 8           81               2
# 4               7                 2            7               2
# 5             229                 7          214               8
# 6              13                22           11               1
# 7             390                45          329               5
# 8              35                 5           32               1
# 9              70                 0           64               2
# 10              1                 0            1               0
# 11             11                 1           11               2
# ..            ...               ...          ...             ...
# 34              0                 0            0               0
# 35             47                13           44               2
# 36            172                92          165               6
# 37             88                 8           67               2
# 38              5                 0            5               0
# 0              60                 6           50               2
# 1              72                 9           47              10
# 2              10                 0            6               1
# 3               0                 0            0              -1
# 4              39                 6           30               2
# 5              80                12           67              10
# 6              22                 1           16               3
# 7             196                21          191               1
# 8              65                 4           50               3
# 9               5                 1            5               1
# 10             27                 0           16               2
# 11              5                 3            2               1
# 12             47                14           33               4
# 13             17                 3           13               3
# 14              2                 2            2               0
# 15             65                29           43               4
# 16             14                12           20               1
# 17             28                10           19               3
# 18             48                 2           35               5
# 19             58                16           32               7
# 20             24                 0           21               4
# 21             17                 3           15               2
# 22             40                 7           33               4
# 23             21                 0           13               0
# 24             57                10           45               4
#
#    anonymousClassesQty subClassesQty lambdasQty uniqueWordsQty modifiers  \
# 0                    6            -2          0            391        24
# 1                    0             0          0             45        17
# 2                   22            -9          1            438        16
# 3                    6            -4          3            561        14
# 4                    2            -1          3            182        16
# 5                   12            -5          3            239        13
# 6                   14            -7          3            248        10
# 7                   52           -25          8            731         1
# 8                    0             0          4            120        17
# 9                    0             0          0             91        17
# 10                   2            -1          0            157        16
# 11                   4            -2          0            111        -1
# 12                   6            -2         31            208        24
# 13                  42           -22          1            781         6
# 14                   8            -4          0             97        13
# 15                   0             0          0             89        17
# 16                   0             0          1            145        17
# 17                   0             0          0             50        17
# 0                    2            -1          3            191        16
# 1                   12            -5          3            239        13
# 2                    6            -2          0            137        40
# 3                   14            -7          3            249        10
# 4                    0             1          0            121        43
# 5                   22            -9          1            450        16
# 6                    0             1          1             90        27
# 7                   42           -22          1            780         6
# 8                    0            23          0            312       537
# 9                    2            -1          0            157        16
# 10                   0             0          0             25         1
# 11                   0             0          0             97        17
# ..                 ...           ...        ...            ...       ...
# 34                   0             0          0              9        17
# 35                   4            -1          0            174        15
# 36                  12            -6          0            423        13
# 37                   0             0          0            235        17
# 38                   0             0          0             16        17
# 0                    0             0          0            578      1025
# 1                    0             5          0            548       114
# 2                    0             0          0            213      1025
# 3                    0             0          0             52         1
# 4                    0            -1          0            256         1
# 5                    4             2          0            323        75
# 6                    0             3          0            381        71
# 7                   24           -13          0            542        25
# 8                    2            -1          0            310         0
# 9                    2            -1          0             31        16
# 10                   0             1          0             88        17
# 11                   0             0          0             52        16
# 12                   0             1          0            290        41
# 13                   0             0          0             84        16
# 14                   0             0          0             12        16
# 15                   2            -1          0            180        16
# 16                   0             0          0             53        16
# 17                   0             1          0            150        27
# 18                   4             0          0            201        26
# 19                   0             2          0            304        53
# 20                   2             1          0             73        35
# 21                   0             0          0             59        17
# 22                   4            -2          0            135        14
# 23                   2            -1          0             40        16
# 24                   2            -1          0            229        16
#
#           time
# 0   2019-07-25
# 1   2019-07-25
# 2   2019-07-25
# 3   2019-07-25
# 4   2019-07-25
# 5   2019-07-25
# 6   2019-07-25
# 7   2019-07-25
# 8   2019-07-25
# 9   2019-07-25
# 10  2019-07-25
# 11  2019-07-25
# 12  2019-07-25
# 13  2019-07-25
# 14  2019-07-25
# 15  2019-07-25
# 16  2019-07-25
# 17  2019-07-25
# 0   2019-05-12
# 1   2019-05-12
# 2   2019-05-12
# 3   2019-05-12
# 4   2019-05-12
# 5   2019-05-12
# 6   2019-05-12
# 7   2019-05-12
# 8   2019-05-12
# 9   2019-05-12
# 10  2019-05-12
# 11  2019-05-12
# ..         ...
# 34  2012-12-21
# 35  2012-12-21
# 36  2012-12-21
# 37  2012-12-21
# 38  2012-12-21
# 0   2012-09-19
# 1   2012-09-19
# 2   2012-09-19
# 3   2012-09-19
# 4   2012-09-19
# 5   2012-09-19
# 6   2012-09-19
# 7   2012-09-19
# 8   2012-09-19
# 9   2012-09-19
# 10  2012-09-19
# 11  2012-09-19
# 12  2012-09-19
# 13  2012-09-19
# 14  2012-09-19
# 15  2012-09-19
# 16  2012-09-19
# 17  2012-09-19
# 18  2012-09-19
# 19  2012-09-19
# 20  2012-09-19
# 21  2012-09-19
# 22  2012-09-19
# 23  2012-09-19
# 24  2012-09-19
#
# [2404 rows x 50 columns]

# %% [markdown]
# ### How many times did we sample from?

# %%
print metricsDataMaven['times']
# Out:
# 47

# %% [markdown]
# ### How many features and samples are in our dataset?

# %%
print metricsDataMaven['data'].shape
# Out:
# (2404, 50)

# %% [markdown]
# ### How many unique source files were measured?

# %%
print metricsDataMaven['data']['entity'].nunique()
# Out:
# 843

# %% [raw]
# # Change Metrics
# ### Let's see what affects the net churn of files
# ### Which metrics have the most impact on churn?

# %%
# We split the data into 5 equally-sized groups, 
# then perform cross-validation while gradually adding these groups to the training set

# i.e. the train-test splits are with groups of size:
# 1-4, 2-3, 3-2, 4-1

# We omit visualization of decision trees to save space,
# but they can be shown with visualize=True as above
folds = 5

from sklearn.tree import DecisionTreeRegressor
modelInstance = DecisionTreeRegressor(max_leaf_nodes=16)
modelSimpler = DecisionTreeRegressor(max_leaf_nodes=8)
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], folds, 'netchurn', modelInstance, modelSimpler, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: 0.637454
#                  name  importance
# 4             deleted    0.624535
# 39  mathOperationsQty    0.240839
# Model.score: 0.777115
#       name  importance
# 4  deleted    0.635034
# 3    added    0.204069
# Model.score: -3.471828
#       name  importance
# 4  deleted    0.632701
# Model.score: 0.608597
#       name  importance
# 4  deleted    0.579622
# 3    added    0.305019
# Model.score: 0.528168
#       name  importance
# 1  deleted    0.807495
# Model.score: 0.562215
#       name  importance
# 1  deleted    0.747642
# Model.score: 0.347597
#       name  importance
# 1  deleted    0.737669
# 0    added    0.262331
# Model.score: 0.391334
#       name  importance
# 1  deleted    0.594465
# 0    added    0.309009
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/utils/__init__.py:93: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(mask.dtype, np.int):

# %%
folds = metricsDataMaven['times'] # This is an attribute of the measured data set: the number of time points measured
churnModelMoreFolds = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], folds, 'netchurn', modelInstance, scoreOnly=False)
# Out:
# Response variable was netchurn
# Model.score: -0.388889
#               name  importance
# 45  uniqueWordsQty        0.32
# Model.score: 0.821747
#       name  importance
# 4  deleted    0.535828
# 3    added    0.260062
# Model.score: 0.688150
#       name  importance
# 4  deleted    0.630941
# 3    added    0.206903
# Model.score: 0.322493
#       name  importance
# 4  deleted    0.518458
# 3    added    0.313540
# Model.score: 0.409541
#       name  importance
# 3    added    0.433840
# 4  deleted    0.281231
# Model.score: 0.107143
#       name  importance
# 3    added    0.506656
# 4  deleted    0.262612
# Model.score: -0.096491
#       name  importance
# 3    added    0.504844
# 4  deleted    0.240271
# Model.score: 0.082657
#       name  importance
# 3    added    0.514366
# 4  deleted    0.242117
# Model.score: 0.235514
#       name  importance
# 3    added    0.387222
# 4  deleted    0.372106
# Model.score: -0.131561
#       name  importance
# 3    added    0.567407
# 4  deleted    0.307207
# Model.score: -0.747202
#       name  importance
# 3    added    0.575552
# 4  deleted    0.300779
# Model.score: 0.039621
#       name  importance
# 3    added    0.596866
# 4  deleted    0.261673
# Model.score: 0.381643
#       name  importance
# 3    added    0.593956
# 4  deleted    0.300893
# Model.score: 0.700349
#       name  importance
# 3    added    0.618359
# 4  deleted    0.303840
# Model.score: -3.047891
#       name  importance
# 3    added    0.659616
# 4  deleted    0.280583
# Model.score: 0.982407
#       name  importance
# 3    added    0.677816
# 4  deleted    0.272545
# Model.score: 0.821000
#       name  importance
# 3    added    0.679516
# 4  deleted    0.258701
# Model.score: 0.458906
#       name  importance
# 3    added    0.667979
# 4  deleted    0.269891
# Model.score: 0.463024
#       name  importance
# 3    added    0.660191
# 4  deleted    0.291698
# Model.score: -0.017400
#       name  importance
# 3    added    0.642278
# 4  deleted    0.290923
# Model.score: 0.368038
#       name  importance
# 3    added    0.648261
# 4  deleted    0.311629
# Model.score: 0.282612
#       name  importance
# 3    added    0.648481
# 4  deleted    0.324233
# Model.score: -0.407976
#       name  importance
# 4  deleted    0.501151
# 3    added    0.463368
# Model.score: 0.690491
#       name  importance
# 4  deleted    0.496332
# 3    added    0.466164
# Model.score: 0.306290
#       name  importance
# 4  deleted    0.495783
# 3    added    0.443603
# Model.score: 0.265699
#       name  importance
# 4  deleted    0.473380
# 3    added    0.425376
# Model.score: 0.558378
#       name  importance
# 4  deleted    0.485835
# 3    added    0.422086
# Model.score: 0.607225
#       name  importance
# 4  deleted    0.515580
# 3    added    0.416735
# Model.score: 0.343603
#       name  importance
# 4  deleted    0.494441
# 3    added    0.425239
# Model.score: 0.268738
#       name  importance
# 4  deleted    0.492329
# 3    added    0.428435
# Model.score: 0.731726
#       name  importance
# 4  deleted    0.512554
# 3    added    0.434114
# Model.score: 0.987481
#       name  importance
# 4  deleted    0.520498
# 3    added    0.431332
# Model.score: 0.472808
#       name  importance
# 4  deleted    0.518217
# 3    added    0.430398
# Model.score: 0.766214
#       name  importance
# 3    added    0.492175
# 4  deleted    0.475732
# Model.score: 0.991258
#       name  importance
# 3    added    0.506258
# 4  deleted    0.451935
# Model.score: 0.787923
#       name  importance
# 4  deleted    0.511912
# 3    added    0.447724
# Model.score: 0.456180
#       name  importance
# 4  deleted    0.540186
# 3    added    0.430898
# Model.score: 0.632316
#       name  importance
# 4  deleted    0.520095
# 3    added    0.453014
# Model.score: 0.998053
#       name  importance
# 4  deleted    0.490442
# 3    added    0.480439
# Model.score: 0.645177
#       name  importance
# 4  deleted    0.552243
# 3    added    0.415415
# Model.score: 0.620824
#       name  importance
# 4  deleted    0.492318
# 3    added    0.481363
# Model.score: 0.853051
#       name  importance
# 4  deleted    0.556427
# 3    added    0.436339
# Model.score: 0.398924
#       name  importance
# 4  deleted    0.494552
# 3    added    0.484483
# Model.score: 0.762499
#       name  importance
# 4  deleted    0.537921
# 3    added    0.449141
# Model.score: -0.710504
#       name  importance
# 4  deleted    0.537106
# 3    added    0.439775
# Model.score: 0.498620
#       name  importance
# 4  deleted    0.531888
# 3    added    0.447999
# Model.score: 0.900794
#     name  importance
# 0  added    0.899545
# Model.score: 0.821747
#       name  importance
# 1  deleted    0.560619
# 0    added    0.373003
# Model.score: 0.688150
#       name  importance
# 1  deleted    0.645919
# 0    added    0.283528
# Model.score: 0.457995
#       name  importance
# 1  deleted    0.537471
# 0    added    0.436333
# Model.score: 0.405772
#       name  importance
# 0    added    0.627055
# 1  deleted    0.312176
# Model.score: 0.219577
#       name  importance
# 0    added    0.642289
# 1  deleted    0.273112
# Model.score: 0.106964
#       name  importance
# 0    added    0.592553
# 1  deleted    0.338530
# Model.score: 0.993655
#       name  importance
# 0    added    0.604513
# 1  deleted    0.348319
# Model.score: 0.883579
#       name  importance
# 1  deleted    0.486324
# 0    added    0.479954
# Model.score: 0.369078
#       name  importance
# 0    added    0.633413
# 1  deleted    0.336814
# Model.score: 0.974487
#       name  importance
# 0    added    0.583817
# 1  deleted    0.398760
# Model.score: 0.736661
#       name  importance
# 0    added    0.685841
# 1  deleted    0.299737
# Model.score: 0.977028
#       name  importance
# 0    added    0.680776
# 1  deleted    0.311838
# Model.score: 0.978615
#       name  importance
# 0    added    0.674546
# 1  deleted    0.310089
# Model.score: 0.026081
#       name  importance
# 0    added    0.658235
# 1  deleted    0.318293
# Model.score: 0.974827
#       name  importance
# 0    added    0.709422
# 1  deleted    0.271580
# Model.score: 0.938761
#       name  importance
# 0    added    0.722973
# 1  deleted    0.270418
# Model.score: 0.904997
#       name  importance
# 0    added    0.664395
# 1  deleted    0.312269
# Model.score: 0.435516
#       name  importance
# 0    added    0.675655
# 1  deleted    0.309814
# Model.score: 0.471063
#       name  importance
# 0    added    0.641873
# 1  deleted    0.349679
# Model.score: 0.538848
#       name  importance
# 0    added    0.658108
# 1  deleted    0.327014
# Model.score: 0.388383
#       name  importance
# 0    added    0.654575
# 1  deleted    0.339152
# Model.score: -0.357118
#       name  importance
# 1  deleted    0.500874
# 0    added    0.485673
# Model.score: 0.774235
#       name  importance
# 1  deleted    0.500694
# 0    added    0.486032
# Model.score: 0.470907
#       name  importance
# 1  deleted    0.527488
# 0    added    0.438623
# Model.score: 0.640723
#       name  importance
# 1  deleted    0.528932
# 0    added    0.450839
# Model.score: 0.670763
#       name  importance
# 1  deleted    0.529115
# 0    added    0.446952
# Model.score: 0.404929
#       name  importance
# 1  deleted    0.529439
# 0    added    0.432979
# Model.score: 0.445869
#       name  importance
# 1  deleted    0.525663
# 0    added    0.448196
# Model.score: 0.532575
#       name  importance
# 1  deleted    0.530792
# 0    added    0.456511
# Model.score: 0.881393
#       name  importance
# 1  deleted    0.527153
# 0    added    0.461344
# Model.score: 0.866789
#       name  importance
# 1  deleted    0.514258
# 0    added    0.468955
# Model.score: 0.711183
#       name  importance
# 1  deleted    0.530484
# 0    added    0.458937
# Model.score: 0.766676
#       name  importance
# 0    added    0.499635
# 1  deleted    0.489255
# Model.score: 0.990157
#       name  importance
# 0    added    0.520274
# 1  deleted    0.470413
# Model.score: 0.791155
#       name  importance
# 1  deleted    0.536716
# 0    added    0.453635
# Model.score: 0.812218
#       name  importance
# 1  deleted    0.544358
# 0    added    0.446472
# Model.score: 0.619758
#       name  importance
# 1  deleted    0.527077
# 0    added    0.463700
# Model.score: 0.996834
#       name  importance
# 0    added    0.505265
# 1  deleted    0.486845
# Model.score: 0.652566
#       name  importance
# 1  deleted    0.559291
# 0    added    0.433044
# Model.score: 0.725813
#       name  importance
# 1  deleted    0.505896
# 0    added    0.487068
# Model.score: 0.853051
#       name  importance
# 1  deleted    0.556427
# 0    added    0.436339
# Model.score: 0.477861
#       name  importance
# 1  deleted    0.504068
# 0    added    0.488705
# Model.score: 0.912594
#       name  importance
# 1  deleted    0.536151
# 0    added    0.456967
# Model.score: -0.202249
#       name  importance
# 1  deleted    0.545280
# 0    added    0.441244
# Model.score: 0.498620
#       name  importance
# 1  deleted    0.531888
# 0    added    0.447999

# %% [markdown]
# ### Results of this step are omitted for printing. However, the large cross-validation can be run to see them.

# %% [markdown]
# ### The individual data sets used for training and testing are quite small and imbalanced.
#
# ### Many of the same relationships still show up.
#
# ### Why is 'deleted' more important factor than 'added'?

# %%
print "Mean", metricsDataMaven['data']['netchurn'].mean()
print "Variance", metricsDataMaven['data']['netchurn'].var()
print "Standard deviation", metricsDataMaven['data']['netchurn'].std()
print "Max", metricsDataMaven['data']['netchurn'].max()
print "Min", metricsDataMaven['data']['netchurn'].min()
# Out:
# Mean -5.468386023294509
# Variance 12577.661505342396
# Standard deviation 112.15017389795878
# Max 996
# Min -2190

# %% [markdown]
# ### This codebase is shrinking slightly (more deleted than added) This may be caused by refactoring
#
# ### Some files must experience more churn than others. We know from some of the motivating literature that defects can be correlated with large pre-release churn.
#
# ### Let's make some categories of binned churn data and classify them

# %%
churnBinnedCategories = ['churnLow','churnMediumLow','churnMediumHigh','churnHigh']
dataSetUpdated = toolkit.utilities.addBinnedResponseCategory(metricsDataMaven['data'], 'netchurn', churnBinnedCategories)

# %%
from sklearn.tree import DecisionTreeClassifier
modelInstance = DecisionTreeClassifier(max_leaf_nodes=8, criterion='entropy')
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMediumLow', 'churnMediumHigh', 'churnHigh']
# Model.score: 0.987510
# accuracy_score: 0.987510
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.38      1.00      0.55         3
#           2       1.00      0.99      0.99      1186
#           3       0.55      0.50      0.52        12
#
# avg / total       0.99      0.99      0.99      1201
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 4  deleted    0.477736
# 3    added    0.396773
# Model.score: 0.178418
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-13a0d95fc5f2> in <module>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 modelInstance = DecisionTreeClassifier(max_leaf_nodes=8, criterion='entropy')
# ----> 3 churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, 2, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
#
# /home/jovyan/work/toolkit/modelRefinement.pyc in makeAndUpdateModel(studyDirectory, data, folds, responseVariable, model, modelRefined, categoryFunction, scoreOnly, visualize)
#      16     return updateModel(studyDirectory, timeModel['data']['features'], timeModel['data']['names'],
#      17                         timeModel['data']['response'], folds, timeModel['fittedModel'],
# ---> 18                         modelRefined if modelRefined is not None else model, scoreOnly, visualize)
#      19
#      20 def selectImportantFeatures(fittedModel, features, featureNames):
#
# /home/jovyan/work/toolkit/modelRefinement.pyc in updateModel(studyDirectory, features, featureNames, responses, folds, fittedModel, modelInstance, scoreOnly, visualize)
#       3
#       4     import modelAnalysis as analysis
# ----> 5     updatedModel = analysis.timeSeriesCV(selectedFeatures['features'], selectedFeatures['names'], responses, folds, modelInstance, scoreOnly=scoreOnly)
#       6
#       7     if visualize is True:
#
# /home/jovyan/work/toolkit/modelAnalysis.pyc in timeSeriesCV(features, featureNames, response, numberOfFolds, model, scoreOnly)
#      51
#      52                 model.fit(cvSplitData['xtr'], cvSplitData['ytr'])
# ---> 53                 analyseModel(model, featureNames, cvSplitData['xte'], cvSplitData['yte'], scoreOnly)
#      54
#      55         return model
#
# /home/jovyan/work/toolkit/modelAnalysis.pyc in analyseModel(model, featureNames, featuresTest, responseTest, scoreOnly)
#      26         if hasattr(model,'classes_') and model.classes_ is not None:
#      27                 from sklearn.metrics import accuracy_score
# ---> 28                 print "accuracy_score: %f" % accuracy_score(responseTest, model.predict(featuresTest))
#      29
#      30                 from sklearn.metrics import classification_report
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# ###

# %%
folds = 5
churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, folds, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was ['churnLow', 'churnMediumLow', 'churnMediumHigh', 'churnHigh']
# Model.score: 0.977035
# accuracy_score: 0.977035
#              precision    recall  f1-score   support
#
#           0       0.33      1.00      0.50         1
#           1       0.00      0.00      0.00         2
#           2       0.98      1.00      0.99       466
#           3       1.00      0.10      0.18        10
#
# avg / total       0.98      0.98      0.97       479
#
# roc_auc_score: 0.675439
#       name  importance
# 4  deleted     0.65455
# Model.score: 0.972860
# accuracy_score: 0.972860
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.33      1.00      0.50         1
#           2       1.00      0.97      0.99       474
#           3       0.27      1.00      0.42         4
#
# avg / total       0.99      0.97      0.98       479
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 4  deleted    0.474622
# 3    added    0.392273
# Model.score: 0.993737
# accuracy_score: 0.993737
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       0.00      0.00      0.00         0
#           2       1.00      1.00      1.00       477
#           3       0.50      0.50      0.50         2
#
# avg / total       1.00      0.99      0.99       479
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 4  deleted    0.462467
# 3    added    0.437132
# Model.score: 0.987474
# accuracy_score: 0.987474
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         0
#           1       1.00      1.00      1.00         3
#           2       1.00      0.99      0.99       469
#           3       0.54      1.00      0.70         7
#
# avg / total       0.99      0.99      0.99       479
#
# roc_auc_score cannot be computed for this test set
#       name  importance
# 4  deleted     0.54503
# 3    added     0.39482
# Model.score: 0.134811
# accuracy_score: 0.977035
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.67      1.00      0.80         2
#           2       0.98      1.00      0.99       466
#           3       0.00      0.00      0.00        10
#
# avg / total       0.96      0.98      0.97       479
#
# roc_auc_score: 0.653584
#       name  importance
# 1  deleted    0.518693
# 0    added    0.312253
# Model.score: 0.546019
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5204ed2456e3> in <module>()
#       1 folds = 5
# ----> 2 churnModelCategories = toolkit.refinement.makeAndUpdateModel(rootDirectory, dataSetUpdated, folds, churnBinnedCategories, modelInstance, modelSimpler, visualize=False, scoreOnly=False)
#
# /home/jovyan/work/toolkit/modelRefinement.pyc in makeAndUpdateModel(studyDirectory, data, folds, responseVariable, model, modelRefined, categoryFunction, scoreOnly, visualize)
#      16     return updateModel(studyDirectory, timeModel['data']['features'], timeModel['data']['names'],
#      17                         timeModel['data']['response'], folds, timeModel['fittedModel'],
# ---> 18                         modelRefined if modelRefined is not None else model, scoreOnly, visualize)
#      19
#      20 def selectImportantFeatures(fittedModel, features, featureNames):
#
# /home/jovyan/work/toolkit/modelRefinement.pyc in updateModel(studyDirectory, features, featureNames, responses, folds, fittedModel, modelInstance, scoreOnly, visualize)
#       3
#       4     import modelAnalysis as analysis
# ----> 5     updatedModel = analysis.timeSeriesCV(selectedFeatures['features'], selectedFeatures['names'], responses, folds, modelInstance, scoreOnly=scoreOnly)
#       6
#       7     if visualize is True:
#
# /home/jovyan/work/toolkit/modelAnalysis.pyc in timeSeriesCV(features, featureNames, response, numberOfFolds, model, scoreOnly)
#      51
#      52                 model.fit(cvSplitData['xtr'], cvSplitData['ytr'])
# ---> 53                 analyseModel(model, featureNames, cvSplitData['xte'], cvSplitData['yte'], scoreOnly)
#      54
#      55         return model
#
# /home/jovyan/work/toolkit/modelAnalysis.pyc in analyseModel(model, featureNames, featuresTest, responseTest, scoreOnly)
#      26         if hasattr(model,'classes_') and model.classes_ is not None:
#      27                 from sklearn.metrics import accuracy_score
# ---> 28                 print "accuracy_score: %f" % accuracy_score(responseTest, model.predict(featuresTest))
#      29
#      30                 from sklearn.metrics import classification_report
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/sklearn/metrics/classification.pyc in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# ### Let's look at this from another point of view. What characterises the files which have the most lines added?

# %%
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, metricsDataMaven['data'], 2, 'added', modelInstance, modelSimpler, visualize=False, scoreOnly=False)

# %% [markdown]
# ### Net churn and deleted lines are strongly related. If we remove some correlated variables, what will we find?

# %%
alteredData = metricsDataMaven['data'].drop(['netchurn','deleted'], axis=1)
addedModel = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData, 2, 'added', modelInstance, modelSimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was added
# Model.score: 0.822648
# accuracy_score: 0.822648
#              precision    recall  f1-score   support
#
#           0       0.87      0.90      0.88       890
#           1       0.68      0.60      0.64       311
#
# avg / total       0.82      0.82      0.82      1201
#
# roc_auc_score: 0.750643
#      name  importance
# 2  n-revs    0.714335
# Model.score: 0.404871
#      name  importance
# 0  n-revs    0.818034

# %% [markdown]
# ### Without the metrics that are directly related to lines added, this model performs quite poorly

# %% [markdown]
# # Java Code Metrics

# %% [markdown]
# ### This model will predict the CBO (Coupling between objects)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=8)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 5, 'cbo', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was cbo
# Model.score: 0.813665
#   name  importance
# 9  dit    0.843451
# Model.score: 0.816961
#   name  importance
# 9  dit    0.796327
# Model.score: 0.564071
#   name  importance
# 9  dit    0.769216
# Model.score: 0.142711
#   name  importance
# 9  dit    0.777959
# Model.score: 0.768300
#   name  importance
# 0  dit    0.917993
# Model.score: 0.663995
#   name  importance
# 0  dit     0.89747
# Model.score: 0.515914
#   name  importance
# 0  dit    0.883342
# Model.score: -0.008641
#   name  importance
# 0  dit    0.897447

# %% [markdown]
# ### We see that the most important feature for predicting coupling between objects for this repository is DIT (Depth of Inheritance Tree). The model performs very poorly.

# %% [markdown]
# ### It seems that the number of unique method invocations in a class is directly related to coupling between objects. What happens if we drop RFC from our dataframe?

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=8)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
alteredData4 = metricsDataMaven['data'].drop(['rfc'],axis=1)
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 5, 'cbo', modelInstanceR, modelInstanceRsimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was cbo
# Model.score: 0.805569
#   name  importance
# 9  dit    0.820508
# Model.score: 0.800914
#   name  importance
# 9  dit    0.810867
# Model.score: 0.562023
#   name  importance
# 9  dit    0.782355
# Model.score: 0.176113
#   name  importance
# 9  dit    0.789694
# Model.score: 0.726180
#   name  importance
# 0  dit     0.90501
# Model.score: 0.672879
#   name  importance
# 0  dit    0.894959
# Model.score: 0.508486
#   name  importance
# 0  dit    0.879026
# Model.score: -0.032085
#   name  importance
# 0  dit    0.907773

# %% [markdown]
# ### The second most important feature for predicting coupling between objects appears to be the total number of variables in a class.

# %% [markdown]
# ### This model will predict the LCOM (Lack of Cohesion of Methods)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=16)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'lcom', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was lcom
# Model.score: 0.808203
#             name  importance
# 12  totalMethods    0.565498
# 21   totalFields    0.196105
# Model.score: 0.774638
#            name  importance
# 0  totalMethods    0.566054
# 1   totalFields    0.196740

# %% [markdown]
# ### We see that the most important feature for predicting lack of cohesion of methods (LCOM) is the total number of methods in a class. This will inflate the LCOM score as the number of methods and LCOM are related
#
# ### What happens if we drop 'publicMethods' and 'totalMethods' from our dataframe?

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=8)
alteredData4 = metricsDataMaven['data'].drop(['publicMethods','totalMethods'],axis=1)
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'lcom', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was lcom
# Model.score: 0.430979
#                  name  importance
# 34  stringLiteralsQty    0.562074
# 22      privateFields    0.199536
# Model.score: 0.386378
#                 name  importance
# 6  stringLiteralsQty    0.570270
# 5        tryCatchQty    0.209891
# 2      privateFields    0.202686

# %% [markdown]
# Looks like the model does much worse. It is interesting that the number of string literals is the discriminating

# %% [markdown]
# ### This model predicts the size of files in terms of lines of code (loc)

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=8)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'loc', modelInstanceR, modelInstanceRsimpler, visualize=True, scoreOnly=False)
# Out:
# Response variable was loc
# Model.score: 0.883702
#               name  importance
# 38  assignmentsQty    0.661039
# 13    totalMethods    0.267195
# Model.score: 0.877514
#              name  importance
# 4  assignmentsQty    0.712147
# 1    totalMethods    0.287853

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=8)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=4)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 2, 'loc', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was loc
# Model.score: 0.868295
#               name  importance
# 38  assignmentsQty    0.838719
# Model.score: 0.833318
#              name  importance
# 4  assignmentsQty    0.903564

# %% [markdown]
# ### The most important feature for predicting size of a file by lines of code is the total number of assignments.

# %% [markdown]
# ### This model predicts the WMC (Weight Method Class) or McCabe's complexity.

# %%
from sklearn.tree import DecisionTreeRegressor
modelInstanceR = DecisionTreeRegressor(max_leaf_nodes=16)
modelInstanceRsimpler = DecisionTreeRegressor(max_leaf_nodes=8)
alteredData4 = metricsDataMaven['data']
nlineModelR = toolkit.refinement.makeAndUpdateModel(rootDirectory, alteredData4, 3, 'wmc', modelInstanceR, modelInstanceRsimpler, visualize=False, scoreOnly=False)
# Out:
# Response variable was wmc
# Model.score: 0.891856
#    name  importance
# 30  loc    0.776272
# Model.score: 0.901264
#    name  importance
# 30  loc    0.924661
# Model.score: 0.900949
#   name  importance
# 4  loc    0.946595
# Model.score: 0.884710
#   name  importance
# 4  loc     0.94952

# %% [markdown]
# ### We can see there is somewhat of a correlation between WMC and the total number of lines. Surprisingly, the correlation is much lower than the Maven dataset

# %%
# We use the Spearman measure of rank correlation
metricsDataMaven['data']['loc'].corr(metricsDataMaven['data']['wmc'], method='spearman')
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/scipy/stats/stats.py:253: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# 0.14600716116236334

# %% [markdown]
# ### In this case study, we have used the toolkit to do the following:
# - Gather the okhttp dataset
# - Create regression models of net churn: above and below the mean, in 3 binned categories (low, medium, high)
# - Create regression models to analyze coupling between objects, lack of cohesion of methods, and weighted method class.
